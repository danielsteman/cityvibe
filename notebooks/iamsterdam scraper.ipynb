# %%
import requests
import json
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import time
import random

# %%
# ==============================================================================
# 1. NORMALIZATION FUNCTIONS (Exact structure provided by you)
# ==============================================================================

def normalize_location_as_event(loc, page_props, url):
    """
    Take a Location block (like AMAZE) and return ONLY the event/visit-related
    fields in a clean, flat structure.
    """
    seo = page_props.get("seo", {})
    localizations = page_props.get("localizations", [])

    images = loc.get("images") or []
    main_image = images[0]["src"] if images else None

    address = loc.get("address") or {}
    coords = loc.get("coordinates") or {}

    return {
        "kind": "Location",
        "id": loc.get("id"),
        "ffID": loc.get("ffID"),
        "slug": loc.get("slug"),
        "name": loc.get("name"),
        "category": loc.get("category", []),

        # SEO / routing
        "directory": page_props.get("directory"),
        "pages": page_props.get("pages", []),
        "seo_title": seo.get("title"),
        "seo_description": seo.get("description"),
        "seo_slug": seo.get("slug"),
        "seo_og_image": seo.get("ogImage"),
        "localizations": localizations,

        # Content
        "intro": loc.get("intro"),
        "description_html": loc.get("description"),

        # Media
        "main_image": main_image,
        "images": images,

        # Visit info
        "alwaysOpen": loc.get("alwaysOpen"),
        "closedDates": loc.get("closedDates"),
        "businessHours": loc.get("businessHours", {}),
        "openUntil": loc.get("openUntil"),
        "soldOut": loc.get("soldOut"),

        # Contact / location
        "address": {
            "street": address.get("street"),
            "houseNumber": address.get("houseNumber"),
            "zipcode": address.get("zipcode"),
            "city": address.get("city"),
        },
        "coordinates": {
            "lat": coords.get("latitude"),
            "lng": coords.get("longitude"),
        },
        "phoneNumber": loc.get("phoneNumber"),
        "email": loc.get("email"),
        "urls": loc.get("urls", []),

        # Commercial info
        "promotions": loc.get("promotions", []),
        
        # Where it came from
        "source_url": url,
    }


def normalize_event(event, page_props, url):
    """
    Normalize real Event pages to match the schema.
    """
    seo = page_props.get("seo", {})
    localizations = page_props.get("localizations", [])

    images = event.get("images") or []
    main_image = images[0]["src"] if images else None

    return {
        "kind": "Event",
        "id": event.get("id"),
        "slug": event.get("slug"),
        "name": event.get("title") or event.get("name"),

        "directory": page_props.get("directory"),
        "pages": page_props.get("pages", []),
        "seo_title": seo.get("title"),
        "seo_description": seo.get("description"),
        "seo_slug": seo.get("slug"),
        "seo_og_image": seo.get("ogImage"),
        "localizations": localizations,

        "intro": event.get("intro"),
        "description_html": event.get("description"),

        "main_image": main_image,
        "images": images,

        "dates": event.get("date") or event.get("dates"),
        "highlights": event.get("highlights", []),

        "source_url": url,
    }

# %%
# ==============================================================================
# 2. PAGE SCRAPER (Logic provided by you)
# ==============================================================================

def scrape_event_page(url):
    try:
        headers = {
            "User-Agent": (
                "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                "AppleWebKit/537.36 (KHTML, like Gecko)"
            )
        }
        # Slight timeout increase for stability
        response = requests.get(url, headers=headers, timeout=15)

        if response.status_code != 200:
            # print(f"Skipping {url} (Status: {response.status_code})")
            return None

        soup = BeautifulSoup(response.content, "html.parser")
        script_tag = soup.find("script", id="__NEXT_DATA__")

        if not script_tag:
            print(f"Error: No __NEXT_DATA__ found in {url}")
            return None

        json_obj = json.loads(script_tag.string)
        page_props = json_obj.get("props", {}).get("pageProps", {}) or {}

        page_type = page_props.get("pageType", "Unknown")

        # ---------- EVENT PAGES ----------
        if (
            page_type == "Event"
            or "event" in page_props
            or "Event" in page_props
        ):
            event = (
                page_props.get("event")
                or page_props.get("Event")
                or page_props.get("data")
            )
            if not event:
                # print(f"No event object found in {url}")
                return None

            return normalize_event(event, page_props, url)

        # ---------- LOCATION PAGES (like AMAZE) ----------
        if (
            page_type == "Location"
            or "Location" in page_props
            or "location" in page_props
        ):
            loc = (
                page_props.get("Location")
                or page_props.get("location")
            )

            # Fallback: some pages inline the location-like data on the root
            if not loc and "name" in page_props:
                loc = page_props

            if not loc:
                # print(f"No Location object found in {url}")
                return None

            return normalize_location_as_event(loc, page_props, url)

        # everything else is not relevant as event data
        return None

    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# %%
# ==============================================================================
# 3. SITEMAP DISCOVERY
# ==============================================================================

def get_sitemap_urls():
    sitemap_url = "https://www.iamsterdam.com/sitemap.xml"
    print(f"Fetching sitemap from: {sitemap_url}")
    
    try:
        response = requests.get(sitemap_url, timeout=30)
        response.raise_for_status()
        
        root = ET.fromstring(response.content)
        # Handle the standard sitemap namespace
        namespace = {'ns': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
        
        all_urls = []
        
        for url_tag in root.findall('ns:url', namespace):
            loc = url_tag.find('ns:loc', namespace).text
            
            # Filter logic: 
            # 1. Must be in /uit/agenda/ (Dutch) or /whats-on/calendar/ (English)
            # 2. Must be deep enough (exclude listing pages)
            if "/uit/agenda/" in loc or "/whats-on/calendar/" in loc:
                # Usually detail pages have 6+ segments: domain / lang / section / sub / category / item
                if len(loc.split("/")) > 6:
                    all_urls.append(loc)
                    
        return list(set(all_urls))
        
    except Exception as e:
        print(f"Critical Error parsing sitemap: {e}")
        return []

# %%
urls = get_sitemap_urls()
print(f"Found {len(urls)} potential event/location URLs in sitemap.")
# Out:
# Fetching sitemap from: https://www.iamsterdam.com/sitemap.xml
# Found 5531 potential event/location URLs in sitemap.

# %%
# ==============================================================================
# SCRAPE 50 RANDOM URLS
# ==============================================================================

# Get all URLs from sitemap (or use existing 'urls' variable if already loaded)
if 'urls' not in locals() or len(urls) == 0:
    urls = get_sitemap_urls()
    print(f"Fetched {len(urls)} URLs from sitemap")

# Select 50 random URLs
random.seed(42)  # For reproducibility
random_urls = random.sample(urls, min(50, len(urls)))
print(f"\nSelected {len(random_urls)} random URLs to scrape")
print(f"First 5 URLs:")
for i, url in enumerate(random_urls[:5], 1):
    print(f"  {i}. {url}")

# Scrape the URLs
print(f"\n{'='*80}")
print("Starting scraping process...")
print(f"{'='*80}\n")

results = []
start_time = time.time()

# Use ThreadPoolExecutor for parallel scraping (10 workers for 50 URLs)
with ThreadPoolExecutor(max_workers=10) as executor:
    futures = {executor.submit(scrape_event_page, url): url for url in random_urls}
    
    processed_count = 0
    for future in futures:
        url = futures[future]
        try:
            data = future.result()
            if data:
                results.append(data)
                print(f"✅ [{processed_count + 1}/{len(random_urls)}] Successfully scraped: {url[:80]}...")
            else:
                print(f"⚠️  [{processed_count + 1}/{len(random_urls)}] No data extracted from: {url[:80]}...")
            
            processed_count += 1
            
        except Exception as exc:
            print(f"❌ [{processed_count + 1}/{len(random_urls)}] Error scraping {url[:80]}...: {exc}")
            processed_count += 1

duration = time.time() - start_time

print(f"\n{'='*80}")
print(f"Scraping completed in {duration:.2f} seconds")
print(f"Successfully extracted data for {len(results)} out of {len(random_urls)} URLs")
print(f"Success rate: {len(results)/len(random_urls)*100:.1f}%")
print(f"{'='*80}\n")

# Display summary
if results:
    print("Summary of scraped items:")
    event_count = sum(1 for r in results if r.get('kind') == 'Event')
    location_count = sum(1 for r in results if r.get('kind') == 'Location')
    print(f"  - Events: {event_count}")
    print(f"  - Locations: {location_count}")
    
    # Show a sample result
    print(f"\nSample result (first item):")
    print(json.dumps(results[0], indent=2, ensure_ascii=False)[:500] + "...")

# Store results in variable for further use
scraped_results = results
# Out:
# Selected 50 random URLs to scrape
# First 5 URLs:
#   1. https://www.iamsterdam.com/uit/agenda/overnachten/accommodaties/de-malle-moolen
#   2. https://www.iamsterdam.com/uit/agenda/winkelen/winkels/beadies
#   3. https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours
#   4. https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge
#   5. https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium
#
# ================================================================================
# Starting scraping process...
# ================================================================================
#
# ✅ [1/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/overnachten/accommodaties/de-malle-moolen...
# ✅ [2/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/winkelen/winkels/beadies...
# ✅ [3/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/tha...
# ✅ [4/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/sma...
# ✅ [5/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/cafes-and-ba...
# ✅ [6/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/eten-en-drinken/restaurants/taiko...
# ✅ [7/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/voorstellingen/theater-en-podiumkunsten/ra...
# ✅ [8/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracti...
# ✅ [9/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/transportation/rental/amsterbike...
# ✅ [10/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/winkelen/winkels/wijnhandel-de-geheime-die...
# ✅ [11/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/beziensw...
# ✅ [12/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/festivals/events/het-vrije-westen...
# ✅ [13/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/concerten-en-muziek/concerten/schellingwou...
# ✅ [14/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/musea-en-galeries/musea/artis-micropia...
# ✅ [15/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/theatre-and-stage/stage/feel-goo...
# ✅ [16/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/sights/th...
# ✅ [17/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/eten-en-drinken/cafes-en-bars/de-kat-in-de...
# ✅ [18/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/vervoer/verhuur/motorbootjes-verhuur-zonne...
# ✅ [19/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/tours/cr...
# ✅ [20/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/accomodations/all-accomodations/...
# ✅ [21/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/festivals/events/head-of-the-riv...
# ✅ [22/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/concerts-and-music/concerts/sund...
# ✅ [23/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/attractio...
# ✅ [24/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/concerten-en-muziek/concerten/textures-jou...
# ✅ [25/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/festivals/events/kunstrai...
# ✅ [26/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/restaurants/...
# ✅ [27/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/festivals/events/pluk-de-nacht-filmfestiva...
# ✅ [28/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/accomodations/all-accomodations/...
# ✅ [29/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/restaurants/...
# ✅ [30/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/musea-en-galeries/musea/art-zoo-museum...
# ✅ [31/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/voorstellingen/theater-en-podiumkunsten/ku...
# ✅ [32/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/eten-en-drinken/cafes-en-bars/poesiat-and-...
# ✅ [33/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/concerten-en-muziek/concerten/jawa-manla-m...
# ✅ [34/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/tours/ip...
# ✅ [35/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/eten-en-drinken/cafes-en-bars/berry-amster...
# ✅ [36/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/festivals/events/holland-festival...
# ✅ [37/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/tentoonstellingen/alle-tentoonstellingen/s...
# ✅ [38/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/voorstellingen/theater-en-podiumkunsten/th...
# ✅ [39/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracti...
# ✅ [40/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/concerten-en-muziek/concerten/noha-sare...
# ✅ [41/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/tours/ci...
# ✅ [42/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/musea-en-galeries/galeries/w139...
# ✅ [43/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/festivals/events/lunar-new-year...
# ✅ [44/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/restaurants/...
# ✅ [45/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/overnachten/accommodaties/prinsen-hotel...
# ✅ [46/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/vip...
# ✅ [47/50] Successfully scraped: https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracti...
# ✅ [48/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/concerts-and-music/concerts/a-uk...
# ✅ [49/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/she...
# ✅ [50/50] Successfully scraped: https://www.iamsterdam.com/en/whats-on/calendar/festivals/events/amsterdam-fring...
#
# ================================================================================
# Scraping completed in 12.39 seconds
# Successfully extracted data for 50 out of 50 URLs
# Success rate: 100.0%
# ================================================================================
#
# Summary of scraped items:
#   - Events: 14
#   - Locations: 36
#
# Sample result (first item):
# {
#   "kind": "Location",
#   "id": "39e0338a-ad92-4718-85ac-4cc34c4f003e",
#   "ffID": "5b068a92adbe1d0001d24654",
#   "slug": "uit/agenda/overnachten/accommodaties/de-malle-moolen",
#   "name": "De Malle Moolen",
#   "category": [
#     {
#       "title": "Accommodaties",
#       "slug": "uit/agenda/overnachten/accommodaties"
#     }
#   ],
#   "directory": "uit",
#   "pages": [
#     "agenda",
#     "overnachten",
#     "accommodaties",
#     "de-malle-moolen"
#   ],
#   "seo_title": "De Malle Moolen",
#   "seo_description": "Hotel...

# %%
scraped_results
# Out:
# [{'kind': 'Location',
#   'id': '39e0338a-ad92-4718-85ac-4cc34c4f003e',
#   'ffID': '5b068a92adbe1d0001d24654',
#   'slug': 'uit/agenda/overnachten/accommodaties/de-malle-moolen',
#   'name': 'De Malle Moolen',
#   'category': [{'title': 'Accommodaties',
#     'slug': 'uit/agenda/overnachten/accommodaties'}],
#   'directory': 'uit',
#   'pages': ['agenda', 'overnachten', 'accommodaties', 'de-malle-moolen'],
#   'seo_title': 'De Malle Moolen',
#   'seo_description': 'Hotel de Mallemolen is een eensterrenhotel gevestigd in een monumentaal pand. Het hotel heeft 13 kamers, met gedeelde badkamer faciliteiten (douche/toilet).',
#   'seo_slug': 'uit/agenda/overnachten/accommodaties/de-malle-moolen',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/63b2fe61cdc49f5de115f2a9/malle_moolen.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/accomodations/all-accomodations/de-malle-moolen'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/overnachten/accommodaties/de-malle-moolen'}],
#   'intro': 'Hotel de Mallemolen is een eensterrenhotel gevestigd in een monumentaal pand. Het hotel heeft 13 kamers, met gedeelde badkamer faciliteiten (douche/toilet).',
#   'description_html': "<p>Het hotel ligt naast Hotel De Koopermoolen waar de receptie is. Daar wordt ook het ontbijtbuffet geserveerd. Er is gratis internet in de lounge beschikbaar. Het hotel beschikt niet over een lift, dus houdt rekening met de trappen.</p><p><strong>Ligging</strong></p><p>In de buurt van het hotel vind je vele gezellige restaurants en café's. Winkelstraten, musea en attracties bevinden zich op loopafstand van het hotel.</p><p>Hotel de Malle Moolen is gemakkelijk te bereiken met de auto of het openbaar vervoer. Vanaf Schiphol gaat er een speciale shuttle bus. Het Centraal Station is op een afstand van 100 meter en diverse parkeergarages liggen vlakbij het hotel.</p>",
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/63b2fe61cdc49f5de115f2a9/malle_moolen.jpg',
#   'images': [{'id': 'fa074d03-d73b-4ec9-9b4f-b488ab4c67b2',
#     'src': 'https://app.thefeedfactory.nl/api/assets/63b2fe61cdc49f5de115f2a9/malle_moolen.jpg',
#     'copyright': 'De Malle Moolen',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': True,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Warmoesstraat',
#    'houseNumber': '7',
#    'zipcode': '1012 HT',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.376102, 'lng': 4.89937},
#   'phoneNumber': '020 535 3222',
#   'email': 'info@mallemoolen.nl',
#   'urls': [{'type': 'Website',
#     'id': 'eb143234-2b59-41b5-955b-96c5322211e4',
#     'url': 'https://www.mallemoolen.nl/'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/overnachten/accommodaties/de-malle-moolen'},
#  {'kind': 'Location',
#   'id': '6ff12455-9ed0-43c5-816a-530d075306a5',
#   'ffID': '5b068ca2adbe1d0001d28714',
#   'slug': 'uit/agenda/winkelen/winkels/beadies',
#   'name': 'Beadies',
#   'category': [{'title': 'Winkels', 'slug': 'uit/agenda/winkelen/winkels'}],
#   'directory': 'uit',
#   'pages': ['agenda', 'winkelen', 'winkels', 'beadies'],
#   'seo_title': 'Beadies',
#   'seo_description': 'Als je Beadies in de Huidenstraat binnenloopt, glimmen de kralen en strass-steentjes je tegemoet. In de fleurige kralen- en sieradenwinkel kun je als creatieveling zelf aan de slag met een overweldigende hoeveelheid kralen, steentjes, bedeltjes en slotjes.',
#   'seo_slug': 'uit/agenda/winkelen/winkels/beadies',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/5ff888a2de7e8633a4aaacb0/bbbce722-d2e7-4732-9406-c8a0d9b8d714.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/shopping/shops/beadies'},
#    {'locale': 'nl-NL', 'slug': 'uit/agenda/winkelen/winkels/beadies'}],
#   'intro': 'Als je Beadies in de Huidenstraat binnenloopt, glimmen de kralen en strass-steentjes je tegemoet. In de fleurige kralen- en sieradenwinkel kun je als creatieveling zelf aan de slag met een overweldigende hoeveelheid kralen, steentjes, bedeltjes en slotjes.',
#   'description_html': '<p>Wil je liever niet zelf aan het werk? Geen probleem: ze hebben hier ook kant-en-klare kettingen, oorbellen en armbandjes.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ff888a2de7e8633a4aaacb0/bbbce722-d2e7-4732-9406-c8a0d9b8d714.jpg',
#   'images': [{'id': 'a065f9e2-bc7b-44ba-809a-2d889934eb48',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff888a2de7e8633a4aaacb0/bbbce722-d2e7-4732-9406-c8a0d9b8d714.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [{'closeDay': 'MONDAY',
#      'closeTime': '18:00',
#      'openDay': 'MONDAY',
#      'openTime': '11:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'TUESDAY',
#      'closeTime': '18:00',
#      'openDay': 'TUESDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'WEDNESDAY',
#      'closeTime': '18:00',
#      'openDay': 'WEDNESDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'THURSDAY',
#      'closeTime': '18:00',
#      'openDay': 'THURSDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'FRIDAY',
#      'closeTime': '18:00',
#      'openDay': 'FRIDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SATURDAY',
#      'closeTime': '18:00',
#      'openDay': 'SATURDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SUNDAY',
#      'closeTime': '18:00',
#      'openDay': 'SUNDAY',
#      'openTime': '12:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False}],
#    'specialHours': []},
#   'openUntil': '18:00',
#   'soldOut': False,
#   'address': {'street': 'Huidenstraat',
#    'houseNumber': '6',
#    'zipcode': '1016 ES',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.368838, 'lng': 4.886056},
#   'phoneNumber': '020 428 5161',
#   'email': None,
#   'urls': [{'type': 'Website',
#     'id': '80f78197-0fc0-4ac4-ab50-fd4ba3152074',
#     'url': 'http://www.beadies.nl/'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/winkelen/winkels/beadies'},
#  {'kind': 'Location',
#   'id': '59103f63-a27c-437b-92fa-e770688cb6a2',
#   'ffID': '60dd7a42eae7cc6fc6da0b12',
#   'slug': 'whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours',
#   'name': 'That Dam Guide - Amsterdam Private Tours',
#   'category': [{'title': 'Tours',
#     'slug': 'whats-on/calendar/attractions-and-sights/tours'}],
#   'directory': 'whats-on',
#   'pages': ['calendar',
#    'attractions-and-sights',
#    'tours',
#    'that-dam-guide-amsterdam-private-tours'],
#   'seo_title': 'That Dam Guide - Amsterdam Private Tours',
#   'seo_description': 'We love providing personal bespoke private tours of Amsterdam and the surrounding countryside that can be shaped to your interests and go at your pace, from quick to leisurely.  That Dam Guide is made up of 5 dedicated guides who have honed our craft for many years and love sharing our beautiful town.',
#   'seo_slug': 'whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/60dd7ba9eae7cc6fc6da0b1b/DamGuide1.jpeg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/tours/that-dam-guide-amsterdam-private-tours'}],
#   'intro': 'We love providing personal bespoke private tours of Amsterdam and the surrounding countryside that can be shaped to your interests and go at your pace, from quick to leisurely.  That Dam Guide is made up of 5 dedicated guides who have honed our craft for many years and love sharing our beautiful town.',
#   'description_html': '<h2>Different private tours on offer</h2>\n<p>We have a wide range of tours available, both walking and driving. &nbsp;Amsterdam lends itself to walking tours in the historic centre and our most popular tour is a 3 hour walk, with breaks of course, that takes in the main sights and gives a great overview of the history and culture of the city. &nbsp;We can have many subject that we can focus the tours on and we discuss this with you by email as part of the booking process: design, business, the Golden Age, Jewish History, Rembrandt and the Rijk Museum, Red Light District. &nbsp;We offer tours to other towns as well, Haarlem, The Hague, Delft, Monnickemdam, Edam and in April we visit Tulip Fields and the rest of the summer we offer authentic Countryside &amp; Windmill experiences.&nbsp;</p>\n<p><a href="https://thatdamguide.com/amsterdam-private-tours/"><u><strong>thatdamguide.com/amsterdam-private-tours/</strong></u></a></p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/60dd7ba9eae7cc6fc6da0b1b/DamGuide1.jpeg',
#   'images': [{'id': 'a7f65ff5-f124-4c93-8e7f-91ef567d40cc',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60dd7ba9eae7cc6fc6da0b1b/DamGuide1.jpeg',
#     'copyright': 'That Dam Guide',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': '97e0017d-8166-4b59-9817-a65121237664',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60dd7bbbeae7cc6fc6da0b1c/DamGuide2.jpeg',
#     'copyright': 'That Dam Guide',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': '53e2685c-f8f6-4995-8a25-a6007d59d60a',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60dd7bd3eae7cc6fc6da0b1d/DamGuide3.jpeg',
#     'copyright': 'That Dam Guide',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Prins Hendrikkade',
#    'houseNumber': None,
#    'zipcode': '1012 AD',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.3766264, 'lng': 4.9005523},
#   'phoneNumber': None,
#   'email': None,
#   'urls': None,
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours'},
#  {'kind': 'Location',
#   'id': '5049665f-6253-4545-ab8b-abfe2361cda2',
#   'ffID': '5b069723adbe1d0001d31a40',
#   'slug': 'whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge',
#   'name': 'Smart Phone City Challenge',
#   'category': [{'title': 'Tours',
#     'slug': 'whats-on/calendar/attractions-and-sights/tours'}],
#   'directory': 'whats-on',
#   'pages': ['calendar',
#    'attractions-and-sights',
#    'tours',
#    'smart-phone-city-challenge'],
#   'seo_title': 'Smart Phone City Challenge',
#   'seo_description': 'Use your smart phone to compete against your colleagues during this fun and friendly event. The company will create a WhatsApp group for every team. An instructor will then send challenges to every group which must be completed at certain locations in Amsterdam. You just have to send photos, videos or messages to prove you have succeeded in each challenge. Not only is it a great way to discover this beautiful city, it’s a fantastic team building exercise.',
#   'seo_slug': 'whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/5ff89448de7e8633a4ab14f2/fe2d9647-edab-48d6-8415-7b6bcf93594d.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/tours/smartphone-city-challenge'}],
#   'intro': 'Use your smart phone to compete against your colleagues during this fun and friendly event. The company will create a WhatsApp group for every team. An instructor will then send challenges to every group which must be completed at certain locations in Amsterdam. You just have to send photos, videos or messages to prove you have succeeded in each challenge. Not only is it a great way to discover this beautiful city, it’s a fantastic team building exercise.',
#   'description_html': 'This event is  <a href="http://www.en.bethereevents.nl/city-games-amsterdam/smarthphone-city-challenge-amsterdam&quot;">bookable with </a>a minimum of ten participants.',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ff89448de7e8633a4ab14f2/fe2d9647-edab-48d6-8415-7b6bcf93594d.jpg',
#   'images': [{'id': 'bc4cc746-9a18-42c7-a53f-ad07016378b4',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff89448de7e8633a4ab14f2/fe2d9647-edab-48d6-8415-7b6bcf93594d.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Oudebrugsteeg',
#    'houseNumber': '9',
#    'zipcode': '1012 JN',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.375538, 'lng': 4.896846},
#   'phoneNumber': '020 767 0094',
#   'email': 'info@bethereevents.nl',
#   'urls': None,
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge'},
#  {'kind': 'Location',
#   'id': '82b91c5d-550c-41f7-b857-9a18dd800aca',
#   'ffID': '5b068ca2adbe1d0001d28724',
#   'slug': 'whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium',
#   'name': 'Palladium',
#   'category': [{'title': 'Cafés and bars',
#     'slug': 'whats-on/calendar/eating-and-drinking/cafes-and-bars'}],
#   'directory': 'whats-on',
#   'pages': ['calendar', 'eating-and-drinking', 'cafes-and-bars', 'palladium'],
#   'seo_title': 'Palladium',
#   'seo_description': "Discover parties with guest DJ's from Thursday through Saturday nights. You won't find a better hot spot to celebrate your next birthday or other special event. With throwback and daily cocktails.\nPalladium serves Modern European classics and high quality local favorites.",
#   'seo_slug': 'whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/63b3f805cdc49f5de1163ab5/palladium.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/eten-en-drinken/cafes-en-bars/palladium'}],
#   'intro': "Discover parties with guest DJ's from Thursday through Saturday nights. You won't find a better hot spot to celebrate your next birthday or other special event. With throwback and daily cocktails.\nPalladium serves Modern European classics and high quality local favorites.",
#   'description_html': None,
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/63b3f805cdc49f5de1163ab5/palladium.jpg',
#   'images': [{'id': '790c5196-2beb-4013-ab08-fced76fb9603',
#     'src': 'https://app.thefeedfactory.nl/api/assets/63b3f805cdc49f5de1163ab5/palladium.jpg',
#     'copyright': 'Palladium Amsterdam',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [{'closeDay': 'TUESDAY',
#      'closeTime': '01:00',
#      'openDay': 'MONDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'WEDNESDAY',
#      'closeTime': '01:00',
#      'openDay': 'TUESDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'THURSDAY',
#      'closeTime': '01:00',
#      'openDay': 'WEDNESDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'FRIDAY',
#      'closeTime': '01:00',
#      'openDay': 'THURSDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SATURDAY',
#      'closeTime': '03:00',
#      'openDay': 'FRIDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SUNDAY',
#      'closeTime': '03:00',
#      'openDay': 'SATURDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'MONDAY',
#      'closeTime': '01:00',
#      'openDay': 'SUNDAY',
#      'openTime': '10:30',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False}],
#    'specialHours': []},
#   'openUntil': '01:00',
#   'soldOut': False,
#   'address': {'street': 'Kleine-Gartmanplantsoen',
#    'houseNumber': '7',
#    'zipcode': '1017 RP',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.362811, 'lng': 4.883481},
#   'phoneNumber': '020 620 5536',
#   'email': None,
#   'urls': None,
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium'},
#  {'kind': 'Location',
#   'id': '4f14d9c9-1da4-4544-8fb9-f33f78872b7a',
#   'ffID': '5b069bb7adbe1d0001d3445c',
#   'slug': 'uit/agenda/eten-en-drinken/restaurants/taiko',
#   'name': 'Taiko',
#   'category': [{'title': 'Restaurants',
#     'slug': 'uit/agenda/eten-en-drinken/restaurants'}],
#   'directory': 'uit',
#   'pages': ['agenda', 'eten-en-drinken', 'restaurants', 'taiko'],
#   'seo_title': 'Taiko',
#   'seo_description': 'Het Aziatische restaurant Taiko, in het Conservatorium Hotel, biedt een uitgebreid menu vol Oosterse heerlijkheden. Er wordt alleen gebruikgemaakt van verse, lokale producten en exclusieve geïmporteerde ingrediënten.',
#   'seo_slug': 'uit/agenda/eten-en-drinken/restaurants/taiko',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/5ff89992de7e8633a4ab4e2a/9fe6571e-31d3-4dd2-9c0b-8258f82c5f0b.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/eating-and-drinking/restaurants/taiko'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/eten-en-drinken/restaurants/taiko'}],
#   'intro': 'Het Aziatische restaurant Taiko, in het Conservatorium Hotel, biedt een uitgebreid menu vol Oosterse heerlijkheden. Er wordt alleen gebruikgemaakt van verse, lokale producten en exclusieve geïmporteerde ingrediënten.',
#   'description_html': '<h2>Noordzeevis en Wagyu Beef</h2><p>Het menu en de aankleding van het restaurant behoren tot het concept van chef Schilo van Coevorden, die veel heeft gereisd en geleerd in Azië. De combinatie van lokale producten met Aziatische smaken zorgt voor een geheel nieuwe kijk op de Aziatische keuken. Als je overweldigd bent door het enorme aanbod op de menukaart kun je kiezen voor een vier- of achtgangenmenu.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ff89992de7e8633a4ab4e2a/9fe6571e-31d3-4dd2-9c0b-8258f82c5f0b.jpg',
#   'images': [{'id': 'bffba64f-a05d-4dc2-8a13-7aeb756ab6ae',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff89992de7e8633a4ab4e2a/9fe6571e-31d3-4dd2-9c0b-8258f82c5f0b.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'ea73fd4a-f7c7-4386-b125-487794db1db0',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff89993de7e8633a4ab4e3c/9abf2d5f-e111-4254-a8dc-0f0f02f9c6d3.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': '51eb0cf1-3cf3-4495-82f4-84ad9eb2044a',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff89994de7e8633a4ab4e4a/f693b846-fd2b-4f81-85f1-287657594eec.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': '41eb7501-1490-4ff1-aa56-b196ac2e195b',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff89995de7e8633a4ab4e55/f92f675c-58a3-490d-a2ed-171bba108999.jpg',
#     'copyright': 'Rinze Vegelien',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [{'closeDay': 'WEDNESDAY',
#      'closeTime': '00:00',
#      'openDay': 'TUESDAY',
#      'openTime': '18:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'THURSDAY',
#      'closeTime': '00:00',
#      'openDay': 'WEDNESDAY',
#      'openTime': '18:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'FRIDAY',
#      'closeTime': '00:00',
#      'openDay': 'THURSDAY',
#      'openTime': '18:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SATURDAY',
#      'closeTime': '00:00',
#      'openDay': 'FRIDAY',
#      'openTime': '18:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SUNDAY',
#      'closeTime': '00:00',
#      'openDay': 'SATURDAY',
#      'openTime': '18:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False}],
#    'specialHours': []},
#   'openUntil': '00:00',
#   'soldOut': False,
#   'address': {'street': 'Van Baerlestraat',
#    'houseNumber': '27',
#    'zipcode': '1071 AN',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.358624, 'lng': 4.878628},
#   'phoneNumber': None,
#   'email': None,
#   'urls': [{'type': 'Website',
#     'id': '6a861875-e76f-4d68-84c8-5af2322bb1df',
#     'url': 'https://www.conservatoriumhotel.com/nl/taiko'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/eten-en-drinken/restaurants/taiko'},
#  {'kind': 'Location',
#   'id': 'f9db5b65-fff6-44b6-9c9e-8a8a0b79b874',
#   'ffID': '5b068cf9adbe1d0001d28f37',
#   'slug': 'uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam',
#   'name': 'RAI Amsterdam',
#   'category': [{'title': 'Theater en podiumkunsten',
#     'slug': 'uit/agenda/voorstellingen/theater-en-podiumkunsten'}],
#   'directory': 'uit',
#   'pages': ['agenda',
#    'voorstellingen',
#    'theater-en-podiumkunsten',
#    'rai-amsterdam'],
#   'seo_title': 'RAI Amsterdam',
#   'seo_description': 'RAI is het bekende conferentiecentrum in Amsterdam, maar er zijn hier ook regelmatig theatervoorstellingen, concerten en musicals.',
#   'seo_slug': 'uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/5ff88988de7e8633a4aab7cb/4c263d3d-86eb-4247-ab4c-56caddd0eb05.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/theatre-and-stage/stage/rai-amsterdam'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam'}],
#   'intro': 'RAI is het bekende conferentiecentrum in Amsterdam, maar er zijn hier ook regelmatig theatervoorstellingen, concerten en musicals.',
#   'description_html': '<h2>Multifunctionele beurslocatie&nbsp;</h2><p>Bij multifunctionele beurslocatie RAI Amsterdam is er ook veel gelegenheid tot ontspanning met theater, toneel, musical en muziek. Er staan met grote regelmaat grote shows, popconcerten, musicals, culinaire festivals en klassieke concerten op het programma.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ff88988de7e8633a4aab7cb/4c263d3d-86eb-4247-ab4c-56caddd0eb05.jpg',
#   'images': [{'id': '765a03a8-7413-438a-9d9a-b1684ba2a0fe',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff88988de7e8633a4aab7cb/4c263d3d-86eb-4247-ab4c-56caddd0eb05.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Europaboulevard',
#    'houseNumber': '22',
#    'zipcode': '1078 RV',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.339047, 'lng': 4.891153},
#   'phoneNumber': '020 549 1212',
#   'email': 'raimarketing@rai.nl',
#   'urls': [{'type': 'Website',
#     'id': '8da7871f-adbc-45cd-aa70-e4c163330e67',
#     'url': 'https://www.rai.nl/theater-bezoeken'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam'},
#  {'kind': 'Location',
#   'id': '7967cafa-c68f-415c-939b-a62c3b81f075',
#   'ffID': '5b06b357adbe1d0001d3deed',
#   'slug': 'uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas',
#   'name': 'Watersportcentrum Sloterplas',
#   'category': [{'title': 'Attracties',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/attracties'}],
#   'directory': 'uit',
#   'pages': ['agenda',
#    'attracties-en-bezienswaardigheden',
#    'attracties',
#    'watersportcentrum-sloterplas'],
#   'seo_title': 'Watersportcentrum Sloterplas',
#   'seo_description': 'Watersportcentrum Sloterplas is de locatie om even lekker buiten te zijn in Amsterdam. Zeilen, suppen, windsurfen, kanoën, waterfietsen en genieten van een drankje op ons terras. Het is bij ons allemaal mogelijk!\nVanuit het watersportcentrum bieden wij cursussen, kinderfeestjes, splashweken, schoolsport en privélessen.\nOnze instructeurs staan altijd voor u klaar om samen voor het optimale te gaan. Van cursus tot privéles, van jong tot oud, alles en iedereen kan bij ons terecht.',
#   'seo_slug': 'uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/5ffeb88df8ee2771764dfe3d/c2449ff2-1dbb-400c-bf5b-bf5f6cd5141c.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/attractions-and-sights/attractions/watersportcentrum-sloterplas'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas'}],
#   'intro': 'Watersportcentrum Sloterplas is de locatie om even lekker buiten te zijn in Amsterdam. Zeilen, suppen, windsurfen, kanoën, waterfietsen en genieten van een drankje op ons terras. Het is bij ons allemaal mogelijk!\nVanuit het watersportcentrum bieden wij cursussen, kinderfeestjes, splashweken, schoolsport en privélessen.\nOnze instructeurs staan altijd voor u klaar om samen voor het optimale te gaan. Van cursus tot privéles, van jong tot oud, alles en iedereen kan bij ons terecht.',
#   'description_html': '<p>Vanuit het watersportcentrum bieden wij onder andere het volgende aan:</p><p><br></p><p><strong> * zeilcursussen</strong>: Wij bieden zeilcursussen op ieder niveau en voor alle leeftijden aan.&nbsp;Zo hebben wij Optimisten voor kinderen vanaf 8 jaar, Laser Vago’s vanaf 12 jaar als u van een echte uitdaging houdt en voor volwassenen ook Laser Vago’s en een Valk indien u de basis van het zeilen onder de knie wilt krijgen.</p><p> Al onze instructeurs zijn erkend opgeleid en worden regelmatig bijgeschoold.</p><p><br></p><p><strong> * kinderfeestjes</strong>:</p><p> Voor kinderen tussen de 8 en 12 jaar hebben wij 3 spetterende watersportfeestjes: kano, vlottenbouwen of optimist zeilen. Alle feestjes worden begeleid door deskundige instructeurs, die ervoor zorgen dat je jouw feestje nooit meer vergeet!</p><p><br></p><p><strong> * Splashweken</strong>:</p><p> De mei- en zomer vakantie beleef je bij ons op het water. Op de doordeweekse dagen kunnen kinderen t/m 11 jaar of jonger meedoen met de ochtend- en/of middagshift van de Splashweek, voor 12 jaar en ouder zijn dit hele dagen. Met wie je komt maakt niet uit. Of je nou alleen komt of met wat vrienden, iedereen is welkom. Onze instructeurs weten namelijk goed hoe ze iedereen bij de groep kunnen betrekken. Hierdoor leert iedereen elkaar goed kennen en ontstaan de mooiste vriendschappen.&nbsp;</p><p><br></p><p> Onze instructeurs staan altijd voor u klaar om samen voor het optimale te gaan. Van cursus tot privéles, van jong tot oud, alles en iedereen kan bij ons terecht.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ffeb88df8ee2771764dfe3d/c2449ff2-1dbb-400c-bf5b-bf5f6cd5141c.jpg',
#   'images': [{'id': '16737f2e-48ec-47b6-9584-98f0c6ed7d06',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ffeb88df8ee2771764dfe3d/c2449ff2-1dbb-400c-bf5b-bf5f6cd5141c.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'f5f3380c-36b8-4eb6-8c04-289d690cf636',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ffeb88ff8ee2771764dfe3e/34b4e172-0371-400d-ba68-ef1ceb58c39d.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [{'closeDay': 'WEDNESDAY',
#      'closeTime': '22:00',
#      'openDay': 'WEDNESDAY',
#      'openTime': '12:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'THURSDAY',
#      'closeTime': '22:00',
#      'openDay': 'THURSDAY',
#      'openTime': '12:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'FRIDAY',
#      'closeTime': '22:00',
#      'openDay': 'FRIDAY',
#      'openTime': '12:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SATURDAY',
#      'closeTime': '22:00',
#      'openDay': 'SATURDAY',
#      'openTime': '10:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False},
#     {'closeDay': 'SUNDAY',
#      'closeTime': '22:00',
#      'openDay': 'SUNDAY',
#      'openTime': '10:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False}],
#    'specialHours': []},
#   'openUntil': '22:00',
#   'soldOut': False,
#   'address': {'street': 'Christoffel Plantijngracht',
#    'houseNumber': '4',
#    'zipcode': '1065 DA',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.360322, 'lng': 4.815835},
#   'phoneNumber': '020 617 5839',
#   'email': 'sloterplas@topsail.nl',
#   'urls': None,
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas'},
#  {'kind': 'Location',
#   'id': '349e1d30-e583-461d-86e7-87813361ca86',
#   'ffID': '5b068badadbe1d0001d26d65',
#   'slug': 'whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery',
#   'name': 'Amsterbike Bike Rental & Delivery',
#   'category': [{'title': 'Rental',
#     'slug': 'whats-on/calendar/transportation/rental'}],
#   'directory': 'whats-on',
#   'pages': ['calendar',
#    'transportation',
#    'rental',
#    'amsterbike-bike-rental-and-delivery'],
#   'seo_title': 'Amsterbike Bike Rental & Delivery',
#   'seo_description': 'Since 2008, AmsterBike has been offering bike rentals, guided tours and delivery for groups and individuals. The bikes have excellent quality with hand brakes, extra locks against theft, gears, and are very well maintained.',
#   'seo_slug': 'whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/60b136b865b7c97410edf818/AH1.JPG',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/vervoer/verhuur/amsterbike-fietsverhuur-and-bezorging'}],
#   'intro': 'Since 2008, AmsterBike has been offering bike rentals, guided tours and delivery for groups and individuals. The bikes have excellent quality with hand brakes, extra locks against theft, gears, and are very well maintained.',
#   'description_html': '<h2>Amsterbike</h2><p>Amsterbike is located at the Passenger Terminal, which is a Cruise Terminal within walking distance of Central Station. You can also have bikes delivered to your location. You can download the Amsterbike app with more than ten different sightseeing tours with spoken explanations via GPS in English, German, French and Spanish.</p><p>You can easily park your car there for 12 euros per day. See the possibilities <a href="https://www.amsterbike.eu/parkandbike" rel="noopener noreferrer" target="_blank">here</a>. You can find more information about bike rental <a href="https://www.amsterbike.eu/rentabike" rel="noopener noreferrer" target="_blank">here</a>. For delivery you will <a href="https://www.amsterbike.eu/bikedelivery" rel="noopener noreferrer" target="_blank">find</a> more information here.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/60b136b865b7c97410edf818/AH1.JPG',
#   'images': [{'id': 'cis_jrpscq2zuu8',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60b136b865b7c97410edf818/AH1.JPG',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'cis_1qm8ns640mn',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60b136ce65b7c97410edf819/AH2.JPG',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'cis_hc83onybfrc',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60b1375565b7c97410edf81a/BR2.JPG',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'cis_k6pfiw47ccg',
#     'src': 'https://app.thefeedfactory.nl/api/assets/60b137b965b7c97410edf81b/Corporate1.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [],
#    'specialHours': [{'closeDay': 'MONDAY',
#      'closeTime': '18:00',
#      'openDay': 'MONDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False},
#     {'closeDay': 'TUESDAY',
#      'closeTime': '18:00',
#      'openDay': 'TUESDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False},
#     {'closeDay': 'WEDNESDAY',
#      'closeTime': '18:00',
#      'openDay': 'WEDNESDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False},
#     {'closeDay': 'THURSDAY',
#      'closeTime': '18:00',
#      'openDay': 'THURSDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False},
#     {'closeDay': 'FRIDAY',
#      'closeTime': '18:00',
#      'openDay': 'FRIDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False},
#     {'closeDay': 'SATURDAY',
#      'closeTime': '18:00',
#      'openDay': 'SATURDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False},
#     {'closeDay': 'SUNDAY',
#      'closeTime': '18:00',
#      'openDay': 'SUNDAY',
#      'openTime': '09:00',
#      'validFrom': '2025-01-01',
#      'validUntil': '2050-01-01',
#      'isClosed': False}]},
#   'openUntil': '18:00',
#   'soldOut': False,
#   'address': {'street': 'Piet Heinkade',
#    'houseNumber': '25',
#    'zipcode': '1019 BR',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.377824, 'lng': 4.915021},
#   'phoneNumber': '+31 20 4199063',
#   'email': 'info@amsterbike.eu',
#   'urls': [{'type': 'Website',
#     'id': 'cis_emx5f8yuxco',
#     'url': 'https://www.amsterbike.eu/book'}],
#   'promotions': [{'id': 'cis_8hah2mecrzs',
#     'productName': 'city card',
#     'productType': None,
#     'description': 'Rent a bike for free for 24 hours with your I amsterdam city card.',
#     'startDate': '2023-12-18 00:00:00',
#     'endDate': '2030-01-01 00:00:00',
#     'published': True,
#     'informationUrl': 'https://www.iamsterdam.com/en/whats-on/calendar?benefits_with_the_city_card=freecard&benefits_with_the_city_card=discountcard&benefits_with_the_city_card=giftcard',
#     'bookingUrl': 'https://www.iamsterdam.com/en/tickets/i-amsterdam-city-card',
#     'isAuthenticatedOnly': False}],
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery'},
#  {'kind': 'Location',
#   'id': '722f91d6-1409-4137-9481-6e805e7de220',
#   'ffID': '6879071b7c674714bad24079',
#   'slug': 'uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst',
#   'name': 'Wijnhandel de Geheime Dienst',
#   'category': [{'title': 'Winkels', 'slug': 'uit/agenda/winkelen/winkels'}],
#   'directory': 'uit',
#   'pages': ['agenda', 'winkelen', 'winkels', 'wijnhandel-de-geheime-dienst'],
#   'seo_title': 'Wijnhandel de Geheime Dienst',
#   'seo_description': 'Je kunt bij ons wijn uit eigen import, bier, frisdrank, alcohol vrij, kaas, olijven en veel meer lekkers kopen in onze winkel aan het Zonneplein in Amsterdam-Noord',
#   'seo_slug': 'uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/687906d67c674714bad24077/24H_Noord_Campagne_1800x1020_1.webp',
#   'localizations': [{'locale': 'nl-NL',
#     'slug': 'uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst'}],
#   'intro': 'Je kunt bij ons wijn uit eigen import, bier, frisdrank, alcohol vrij, kaas, olijven en veel meer lekkers kopen in onze winkel aan het Zonneplein in Amsterdam-Noord',
#   'description_html': None,
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/687906d67c674714bad24077/24H_Noord_Campagne_1800x1020_1.webp',
#   'images': [{'id': '645d9c52-e51e-4d36-94e0-56bcfca91008',
#     'src': 'https://app.thefeedfactory.nl/api/assets/687906d67c674714bad24077/24H_Noord_Campagne_1800x1020_1.webp',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': '...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [{'closeDay': 'SATURDAY',
#      'closeTime': '17:00',
#      'openDay': 'SATURDAY',
#      'openTime': '11:00',
#      'validFrom': None,
#      'validUntil': None,
#      'isClosed': False}],
#    'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Zonneplein',
#    'houseNumber': '21',
#    'zipcode': '1033 EJ',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.4133694, 'lng': 4.890432199999999},
#   'phoneNumber': '06-14239470',
#   'email': 'pssst@geheimedienst.eu',
#   'urls': [{'type': 'Website',
#     'id': '31d5c62e-9f63-48ff-b7ee-fd4f87e65455',
#     'url': 'https://www.geheimedienst.eu'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst'},
#  {'kind': 'Location',
#   'id': '49dc300e-5a23-43e3-b74b-894f2db98eb6',
#   'ffID': '68aedb50d074a82752e0ca51',
#   'slug': 'uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert',
#   'name': 'R.-K. Begraafplaats Buitenveldert',
#   'category': [{'title': 'Bezienswaardigheden',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden'}],
#   'directory': 'uit',
#   'pages': ['agenda',
#    'attracties-en-bezienswaardigheden',
#    'bezienswaardigheden',
#    'r-k-begraafplaats-buitenveldert'],
#   'seo_title': 'R.-K. Begraafplaats Buitenveldert',
#   'seo_description': None,
#   'seo_slug': 'uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/68aedb4ed074a82752e0ca50/natasjafotografeert-2348.webp',
#   'localizations': [{'locale': 'nl-NL',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert'}],
#   'intro': None,
#   'description_html': None,
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/68aedb4ed074a82752e0ca50/natasjafotografeert-2348.webp',
#   'images': [{'id': '6500d6e9-9d70-4241-8b7a-fc48f0771aab',
#     'src': 'https://app.thefeedfactory.nl/api/assets/68aedb4ed074a82752e0ca50/natasjafotografeert-2348.webp',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': '...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Fred. Roeskestraat',
#    'houseNumber': '103',
#    'zipcode': '1076 EE',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.34082799999999, 'lng': 4.861535},
#   'phoneNumber': None,
#   'email': 'info@begraafplaats-buitenveldert.nl',
#   'urls': [{'type': 'Website',
#     'id': '54b287e2-8b3c-4789-a9d8-e2373df4069c',
#     'url': 'https://begraafplaats-buitenveldert.nl'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert'},
#  {'kind': 'Event',
#   'id': '7be1b8d8-b71e-48c2-849f-0bdbd898ef50',
#   'slug': 'uit/agenda/festivals/events/het-vrije-westen',
#   'name': 'Het Vrije Westen',
#   'directory': 'uit',
#   'pages': ['agenda', 'festivals', 'events', 'het-vrije-westen'],
#   'seo_title': 'Het Vrije Westen',
#   'seo_description': 'Een van de grootste Bevrijdingsfestivals in Amsterdam is Het Vrije Westen. Dit is wel de plek waar je moet zijn als je van muziek houdt.  Ga naar het Westerpark voor veel livemuziek en nog veel meer. Natuurlijk hopen wij in 2026 terug te keren om wederom met elkaar de vrijheid te vieren.',
#   'seo_slug': 'uit/agenda/festivals/events/het-vrije-westen',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/600ab344caf0505bd4cf8310/cf735b61-a960-44b5-a63e-c35a586d02a5.jpg',
#   'localizations': [{'locale': 'nl-NL',
#     'slug': 'uit/agenda/festivals/events/het-vrije-westen'}],
#   'intro': 'Een van de grootste Bevrijdingsfestivals in Amsterdam is Het Vrije Westen. Dit is wel de plek waar je moet zijn als je van muziek houdt.  Ga naar het Westerpark voor veel livemuziek en nog veel meer. Natuurlijk hopen wij in 2026 terug te keren om wederom met elkaar de vrijheid te vieren.',
#   'description_html': '<h2>Vrijheid is voor iedereen, maar niet vanzelfsprekend</h2><p>Dat vrijheid nooit als vanzelfsprekendheid mag worden ervaren is de afgelopen jaren door de situatie in de wereld helaas pijnlijk duidelijk geworden.  Vier de vrijheid samen met duizenden anderen en laat zien dat vrijheid iets is dat we samen beleven.</p><p>Dit festival is voor iedereen <strong>gratis</strong> toegankelijk en het is <strong>pin-only.</strong> Bekijk de <a href="http://www.hetvrijewesten.eu/" rel="noopener noreferrer" target="_blank">website</a> van het Vrije Westen voor het volledige programma. </p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/600ab344caf0505bd4cf8310/cf735b61-a960-44b5-a63e-c35a586d02a5.jpg',
#   'images': [{'id': '776666d3-3554-4dec-9c35-4e55ab162770',
#     'src': 'https://app.thefeedfactory.nl/api/assets/600ab344caf0505bd4cf8310/cf735b61-a960-44b5-a63e-c35a586d02a5.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'dates': None,
#   'highlights': [],
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/festivals/events/het-vrije-westen'},
#  {'kind': 'Location',
#   'id': '01b5c6e1-29c7-4c4d-9dc0-e27394a84e62',
#   'ffID': '5b06abcdadbe1d0001d3b528',
#   'slug': 'uit/agenda/concerten-en-muziek/concerten/schellingwouderkerk',
#   'name': 'Schellingwouderkerk',
#   'category': [{'title': 'Concerten',
#     'slug': 'uit/agenda/concerten-en-muziek/concerten'}],
#   'directory': 'uit',
#   'pages': ['agenda',
#    'concerten-en-muziek',
#    'concerten',
#    'schellingwouderkerk'],
#   'seo_title': 'Schellingwouderkerk',
#   'seo_description': 'De Schellingwouderkerk is de kleinste kerk in beheer van Stadsherstel.',
#   'seo_slug': 'uit/agenda/concerten-en-muziek/concerten/schellingwouderkerk',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/5ff8be28de7e8633a4abe99b/4da3ba93-ad9b-4f0d-89e2-14e82054cd67.jpg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/concerts-and-music/concerts/schellingwouderkerk'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/concerten-en-muziek/concerten/schellingwouderkerk'}],
#   'intro': 'De Schellingwouderkerk is de kleinste kerk in beheer van Stadsherstel.',
#   'description_html': '<h2>Landelijke en pittoreske ligging</h2><p>Door de landelijke en pittoreske ligging is het een romantische locatie voor het sluiten van huwelijken. Het orgel wordt nog steeds bespeeld.&nbsp;</p><p>Ook is de kerk ook uitermate geschikt voor workshops, diners, kleine congressen, concerten of lezingen. De kerk is dagelijks van 9:00 tot middernacht te reserveren en is goed bereikbaar per auto en per boot.&nbsp;</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ff8be28de7e8633a4abe99b/4da3ba93-ad9b-4f0d-89e2-14e82054cd67.jpg',
#   'images': [{'id': '60e595fa-5fa0-44cc-8ffa-fc229dcb9606',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff8be28de7e8633a4abe99b/4da3ba93-ad9b-4f0d-89e2-14e82054cd67.jpg',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Wijkergouw',
#    'houseNumber': '6',
#    'zipcode': '1023 NX',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.383545, 'lng': 4.965339},
#   'phoneNumber': '020 520 0090',
#   'email': None,
#   'urls': [{'type': 'Website',
#     'id': 'c9c453a3-37c4-44cc-9d32-453f59105f4a',
#     'url': 'https://www.stadsherstel.nl/66/schellingwouderkerk/'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/concerten-en-muziek/concerten/schellingwouderkerk'},
#  {'kind': 'Location',
#   'id': '3945a592-1dd0-4957-ac4c-27be7cf649d7',
#   'ffID': '5b069c41adbe1d0001d348fb',
#   'slug': 'uit/agenda/musea-en-galeries/musea/artis-micropia',
#   'name': 'ARTIS-Micropia',
#   'category': [{'title': 'Musea',
#     'slug': 'uit/agenda/musea-en-galeries/musea'}],
#   'directory': 'uit',
#   'pages': ['agenda', 'musea-en-galeries', 'musea', 'artis-micropia'],
#   'seo_title': 'ARTIS-Micropia',
#   'seo_description': 'ARTIS-Micropia viert haar tienjarig bestaan! Kom en ontdek de onzichtbare wereld van microben via interactieve opstellingen, 40 verschillende soorten levende microben en de Laborant Vertelt, een mini-college met elke maand een nieuw onderwerp.\n\nARTIS-Micropia ligt in het centrum van Amsterdam. Neem tram 14 vanaf Amsterdam Centraal naar ARTIS. Ook tramlijnen 7 en 19 stoppen in de buurt. Metrostation Waterlooplein ligt op 10 minuten lopen.',
#   'seo_slug': 'uit/agenda/musea-en-galeries/musea/artis-micropia',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/66f6c4a2163f6d24f8122c34/906x620px-beeldmicropia.webp',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/museums-and-galleries/museums/artis-micropia'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/musea-en-galeries/musea/artis-micropia'}],
#   'intro': 'ARTIS-Micropia viert haar tienjarig bestaan! Kom en ontdek de onzichtbare wereld van microben via interactieve opstellingen, 40 verschillende soorten levende microben en de Laborant Vertelt, een mini-college met elke maand een nieuw onderwerp.\n\nARTIS-Micropia ligt in het centrum van Amsterdam. Neem tram 14 vanaf Amsterdam Centraal naar ARTIS. Ook tramlijnen 7 en 19 stoppen in de buurt. Metrostation Waterlooplein ligt op 10 minuten lopen.',
# ...
#   'intro': 'Het Woeste Westen is niet zomaar een speeltuin: het is een waar avontuur voor kinderen tot 13 jaar. In de noordwesthoek van het Amsterdamse Westerpark ontdekken kinderen de natuur. Ze kunnen er lekker rondrennen, met zand en water spelen, een hut bouwen, op een vlot varen, insecten bewonderen, spelen in een stromende beek en door riet en bosjes struinen.',
#   'description_html': '<h2>Een stuk natuur waar heerlijk kunt spelen</h2><p>In de Woeste Westen kun je graven, klimmen, in het zand spelen, door de beekjes waden en een boeket wilde bloemen plukken. Of kikkers en insecten inspecteren en kennismaken met alle dieren die in het park wonen. Kinderen worden aangemoedigd om zelf te spelen terwijl ouders ontspannen met een drankje op het terras.</p><p>Er is een speeltuinbegeleider aanwezig op woensdag, zaterdag en zondag van 11:00 - 18:00 uur en de rest van de week van 12:00 - 18:00 uur. Tijdens deze tijd kun je ook versnaperingen kopen. Omdat de speeltuin openbaar terrein is, is hij altijd open - zelfs als er geen toezichthouder is.</p><p>De Woeste Westen is een geweldige plek voor een verjaardagsfeestje. Naast gewoon genieten van de speeltuin, kun je ook allerlei speciale activiteiten organiseren, zoals katapulten maken of kampvuren leren bouwen.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/5ff88c2bde7e8633a4aad184/a5e6ea7c-a470-4fc4-91b0-bb050c3d2719.jpg',
#   'images': [{'id': 'bfa0a13a-7eff-4ff0-a6ad-a379f2d1a576',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff88c2bde7e8633a4aad184/a5e6ea7c-a470-4fc4-91b0-bb050c3d2719.jpg',
#     'copyright': 'Woeste Westen',
#     'alt': None,
#     'title': 'Woeste Westen',
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': '6862feff-bc2c-4d90-be30-c6ed0ec990b1',
#     'src': 'https://app.thefeedfactory.nl/api/assets/5ff88c2cde7e8633a4aad18d/aacf6b09-fb35-4db9-beb1-1c2121bb116e.jpg',
#     'copyright': 'Woeste Westen',
#     'alt': None,
#     'title': 'Woeste Westen',
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'alwaysOpen': False,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Overbrakerpad',
#    'houseNumber': '3',
#    'zipcode': '1014 AZ',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.390734, 'lng': 4.865178},
#   'phoneNumber': None,
#   'email': 'info@woestewesten.nl',
#   'urls': [{'type': 'Website',
#     'id': '67071fd1-0026-4fef-8504-7e01e24c9715',
#     'url': 'https://www.woestewesten.nl/'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracties/woeste-westen'},
#  {'kind': 'Event',
#   'id': '58ba70ed-889f-4b00-a05b-9d786938fbd9',
#   'slug': 'whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble',
#   'name': 'A Ukrainian Christmas Partes Ensemble',
#   'directory': 'whats-on',
#   'pages': ['calendar',
#    'concerts-and-music',
#    'concerts',
#    'a-ukrainian-christmas-partes-ensemble'],
#   'seo_title': 'A Ukrainian Christmas Partes Ensemble',
#   'seo_description': 'Partes Ensemble presents Ukrainian Baroque masterpieces from the 17th and 18th centuries, when Kiev and Lviv were crossroads of musical traditions. Theoretician-composer Mykola Dyletsky brought Italian influences to the East, while child prodigy Maksym Berezovsky propelled the choral concerto to new heights.',
#   'seo_slug': 'whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/690a9d86f1ba792b6f15ff93/aHR0cHM6Ly93d3cubXV6aWVrZ2Vib3V3Lm5sLy9jbXNfZmlsZXMvc3lzdGVtL2ltYWdlcy9pbWc4MjM4M19vcmlnLmpwZw.webp',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/concerten-en-muziek/concerten/een-oekraiense-kerst-partes-ensemble'}],
#   'intro': 'Partes Ensemble presents Ukrainian Baroque masterpieces from the 17th and 18th centuries, when Kiev and Lviv were crossroads of musical traditions. Theoretician-composer Mykola Dyletsky brought Italian influences to the East, while child prodigy Maksym Berezovsky propelled the choral concerto to new heights.',
#   'description_html': '<h2>An enchanting winter landscape</h2><p>In powerful 12-part chants and intense four-part miniatures, an enchanting winter wonderland unfolds. Partes brings not only music but also the soul of Ukraine to life.</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/690a9d86f1ba792b6f15ff93/aHR0cHM6Ly93d3cubXV6aWVrZ2Vib3V3Lm5sLy9jbXNfZmlsZXMvc3lzdGVtL2ltYWdlcy9pbWc4MjM4M19vcmlnLmpwZw.webp',
#   'images': [{'id': '310d913b-e90c-4b11-9239-7fdd08a7d56a',
#     'src': 'https://app.thefeedfactory.nl/api/assets/690a9d86f1ba792b6f15ff93/aHR0cHM6Ly93d3cubXV6aWVrZ2Vib3V3Lm5sLy9jbXNfZmlsZXMvc3lzdGVtL2ltYWdlcy9pbWc4MjM4M19vcmlnLmpwZw.webp',
#     'copyright': None,
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/jpeg;base64,...'}],
#   'dates': None,
#   'highlights': [],
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble'},
#  {'kind': 'Location',
#   'id': '8233108f-5bc8-4aa4-8520-6bd96db2b3bc',
#   'ffID': '649bf08dc9c2663697299ff5',
#   'slug': 'whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game',
#   'name': 'Sherlock Holmes Murder Mystery City Game',
#   'category': [{'title': 'Tours',
#     'slug': 'whats-on/calendar/attractions-and-sights/tours'}],
#   'directory': 'whats-on',
#   'pages': ['calendar',
#    'attractions-and-sights',
#    'tours',
#    'sherlock-holmes-murder-mystery-city-game'],
#   'seo_title': 'Sherlock Holmes Murder Mystery City Game',
#   'seo_description': 'The Sherlock Holmes City Game is a self-guided tour that gives you a fun and interactive way to walk around the city. All you need is a phone with an internet connection. As soon as you book the game, we will send you all the information you need via email.\n\nBy moving around the city, you will unlock assignments. Here you will find characters who are willing to help. But the information comes at a price! Solve their puzzles, take on hilarious photo challenges, chase down culprits and play along to get closer to solving the murder of Balthasar.',
#   'seo_slug': 'whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/64acd9ea05b0181027a05a77/Stadsspel_in_Amsterdam.jpeg',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/attracties-en-bezienswaardigheden/tours/sherlock-holmes-moordmysterie-stadsspel'}],
#   'intro': 'The Sherlock Holmes City Game is a self-guided tour that gives you a fun and interactive way to walk around the city. All you need is a phone with an internet connection. As soon as you book the game, we will send you all the information you need via email.\n\nBy moving around the city, you will unlock assignments. Here you will find characters who are willing to help. But the information comes at a price! Solve their puzzles, take on hilarious photo challenges, chase down culprits and play along to get closer to solving the murder of Balthasar.',
#   'description_html': "<h2>Important Information</h2><ul><li>Difficulty level: easy – also suitable for families with children</li><li>Duration:&nbsp;2 hours</li><li>Tickets: You only need to buy 1 ticket per group (1-4 people)</li><li>Each group will play with 1 device. For groups of more than 4 people, you can buy 2 or more tickets.</li><li>To book this game you need to indicate a date and time, but you can start whenever you like.</li></ul><p><br></p><h2>How to play</h2><p>Book the City Game, check the email we send you with the instructions, download the Loquiz App, and begin your gaming experience.</p><h2>What makes the game unique?</h2><p>Explore the city at your own pace while playing the Sherlock Holmes City Game, a self-guided tour that offers a lot of freedom and flexibility. You can play when, where and with whomever you want.</p><p>Whether you want to play alone for personal excitement or with a group of people, this is the game for you.&nbsp;Playing with more groups will turn into a competitive experience, perfect as a teambuilding activity. This game is a fun activity you can do while visiting a city with your family and friends.</p><p>City Game offers the maximum independence: you can play, pause and continue whenever you want. Solve the murder of Balthazar! A fun activity to do when visiting a city with your family or as a couple. 'Sherlock Holmes' is filled with brain teasers, puzzles, hilarious photo tasks, and British humor.</p><p>The Game Sherlock Holmes takes about 1.5 hours, but there is no time limit. You can finish it at your own pace. After you booked the game, you will receive a login code and a simple manual by email. The email contains a QR code, which you can use to easily download the app. You don't need a guide: just download the app, go to the starting point, and you are ready to start the adventure. We recommend playing with 2 to 4 people on one device. Only buy 1 credit per device. If you are playing with more than 4 people, you can buy 2 or more credits.</p><p>Note: this Game uses the city as an interactive playing field, but does not provide any information about the city!</p>",
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/64acd9ea05b0181027a05a77/Stadsspel_in_Amsterdam.jpeg',
#   'images': [{'id': '2b26da40-df8a-46b7-9fc0-4dd777d9e361',
#     'src': 'https://app.thefeedfactory.nl/api/assets/64acd9ea05b0181027a05a77/Stadsspel_in_Amsterdam.jpeg',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': 'Stadsspel in Amsterdam',
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'f67f2d3b-a53a-4b65-9c8c-05e21f374477',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29fb/Sherlock_2.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'},
#    {'id': '9047fb80-08a4-47d1-9206-09f6280eccb4',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29f6/Sherlock_3.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'},
#    {'id': '9eecc340-4c24-41e0-a67f-d109758d2c5c',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29f7/Sherlock_4.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'},
#    {'id': 'a685aca3-3a2d-45bf-b362-8d2bd97d50bb',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29f8/Sherlock_5.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'},
#    {'id': '3fd71170-30d2-4107-a7f9-9d6e73faff23',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8cebc32a15c8cb29fc/Sherlock_6.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'},
#    {'id': '45f3773d-863b-44b3-b180-2c38d83faa66',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29fa/Sherlock_7.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'},
#    {'id': '1dd287f0-5b20-4877-88e9-e054d874b412',
#     'src': 'https://app.thefeedfactory.nl/api/assets/649bef14c9c2663697299feb/Up_Events__Sherlock.jpg',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': 'Sherlock Holmes Stadsspel in Amsterdam',
#     'blurDataURL': 'data:image/jpeg;base64,...'},
#    {'id': 'fa706cfa-8bbb-4062-b966-83a10b2376fa',
#     'src': 'https://app.thefeedfactory.nl/api/assets/65979a8aebc32a15c8cb29f4/Sherlock_9.png',
#     'copyright': 'UP Digital',
#     'alt': None,
#     'title': None,
#     'blurDataURL': 'data:image/png;base64,...'}],
#   'alwaysOpen': True,
#   'closedDates': None,
#   'businessHours': {'regularHours': [], 'specialHours': []},
#   'openUntil': None,
#   'soldOut': False,
#   'address': {'street': 'Beursplein',
#    'houseNumber': '5',
#    'zipcode': '1012 JW',
#    'city': 'Amsterdam'},
#   'coordinates': {'lat': 52.374333632042685, 'lng': 4.895187846449609},
#   'phoneNumber': '+31(0)23 2052340',
#   'email': 'hello@citygame.com',
#   'urls': [{'type': 'Website',
#     'id': '4c7bbdd7-e642-406b-a3fe-44af131409dd',
#     'url': 'https://citygame.com/event/sherlock-holmes-amsterdam/'}],
#   'promotions': None,
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game'},
#  {'kind': 'Event',
#   'id': '50af38d4-6990-47bf-94b0-01ddf8368376',
#   'slug': 'whats-on/calendar/festivals/events/amsterdam-fringe-festival',
#   'name': 'Amsterdam Fringe Festival',
#   'directory': 'whats-on',
#   'pages': ['calendar', 'festivals', 'events', 'amsterdam-fringe-festival'],
#   'seo_title': 'Amsterdam Fringe Festival',
#   'seo_description': 'In September 2026 Amsterdam Fringe Festival presents a new edition with a mix mash of theatre, performance and dance from new, emerging and untamed talent for 11 days. The whole city is our playground; from boat to club to theater, from North to South, you will find us for 11 days at about 22 locations throughout Amsterdam. The festival is an ode to theatrical madness, the independent spirit and a plea for artistic freedom. The program promises another intriguing mix of performances. Please note: Dates and times for 2026 are subject to change',
#   'seo_slug': 'whats-on/calendar/festivals/events/amsterdam-fringe-festival',
#   'seo_og_image': 'https://app.thefeedfactory.nl/api/assets/687a0b777c674714bad2c53c/Fringe_-_1920x1080_V1__1_.webp',
#   'localizations': [{'locale': 'en-GB',
#     'slug': 'whats-on/calendar/festivals/events/amsterdam-fringe-festival'},
#    {'locale': 'nl-NL',
#     'slug': 'uit/agenda/festivals/events/amsterdam-fringe-festival'}],
#   'intro': 'In September 2026 Amsterdam Fringe Festival presents a new edition with a mix mash of theatre, performance and dance from new, emerging and untamed talent for 11 days. The whole city is our playground; from boat to club to theater, from North to South, you will find us for 11 days at about 22 locations throughout Amsterdam. The festival is an ode to theatrical madness, the independent spirit and a plea for artistic freedom. The program promises another intriguing mix of performances. Please note: Dates and times for 2026 are subject to change',
#   'description_html': '<h2>International allure</h2><p>The Amsterdam Fringe Festival is inspired by the festival of the same name in Edinburgh, Adelaide, New York and Dublin. A dive into the Fringe means a dive into the unknown: plunge into the underground, discover the hits of tomorrow and be amazed by a world you never knew existed.</p><h2>Practical information</h2><p>With an appealing international line-up, English speakers can also fully enjoy the Fringe Festival. The starting times indicated are the times of the performance that starts earliest. For detailed information, see the <a href="https://amsterdamfringefestival.nl/" rel="noopener noreferrer" target="_blank">Fringe website</a> .</p>',
#   'main_image': 'https://app.thefeedfactory.nl/api/assets/687a0b777c674714bad2c53c/Fringe_-_1920x1080_V1__1_.webp',
#   'images': [{'id': '5ba79de5-7dc5-4d7f-818e-a0e91f897686',
#     'src': 'https://app.thefeedfactory.nl/api/assets/687a0b777c674714bad2c53c/Fringe_-_1920x1080_V1__1_.webp',
#     'copyright': None,
#     'alt': None,
#     'title': 'Amsterdam Fringe Festival 2025',
#     'blurDataURL': '...'}],
#   'dates': None,
#   'highlights': [],
#   'source_url': 'https://www.iamsterdam.com/en/whats-on/calendar/festivals/events/amsterdam-fringe-festival'}]

# %%
# ==============================================================================
# PRETTY PRINT JSON RESULTS
# ==============================================================================

# Check if we have results to display
if 'scraped_results' in locals() and scraped_results:
    print(f"Pretty printing {len(scraped_results)} results:\n")
    print("=" * 80)
    print(json.dumps(scraped_results, indent=2, ensure_ascii=False))
    print("=" * 80)
elif 'results' in locals() and results:
    print(f"Pretty printing {len(results)} results:\n")
    print("=" * 80)
    print(json.dumps(results, indent=2, ensure_ascii=False))
    print("=" * 80)
else:
    print("No results found. Please run the scraping cell first.")
    print("Available variables:", [k for k in locals().keys() if not k.startswith('_')])
# Out:
# Pretty printing 50 results:
#
# ================================================================================
# [
#   {
#     "kind": "Location",
#     "id": "39e0338a-ad92-4718-85ac-4cc34c4f003e",
#     "ffID": "5b068a92adbe1d0001d24654",
#     "slug": "uit/agenda/overnachten/accommodaties/de-malle-moolen",
#     "name": "De Malle Moolen",
#     "category": [
#       {
#         "title": "Accommodaties",
#         "slug": "uit/agenda/overnachten/accommodaties"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "overnachten",
#       "accommodaties",
#       "de-malle-moolen"
#     ],
#     "seo_title": "De Malle Moolen",
#     "seo_description": "Hotel de Mallemolen is een eensterrenhotel gevestigd in een monumentaal pand. Het hotel heeft 13 kamers, met gedeelde badkamer faciliteiten (douche/toilet).",
#     "seo_slug": "uit/agenda/overnachten/accommodaties/de-malle-moolen",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/63b2fe61cdc49f5de115f2a9/malle_moolen.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/accomodations/all-accomodations/de-malle-moolen"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/overnachten/accommodaties/de-malle-moolen"
#       }
#     ],
#     "intro": "Hotel de Mallemolen is een eensterrenhotel gevestigd in een monumentaal pand. Het hotel heeft 13 kamers, met gedeelde badkamer faciliteiten (douche/toilet).",
#     "description_html": "<p>Het hotel ligt naast Hotel De Koopermoolen waar de receptie is. Daar wordt ook het ontbijtbuffet geserveerd. Er is gratis internet in de lounge beschikbaar. Het hotel beschikt niet over een lift, dus houdt rekening met de trappen.</p><p><strong>Ligging</strong></p><p>In de buurt van het hotel vind je vele gezellige restaurants en café's. Winkelstraten, musea en attracties bevinden zich op loopafstand van het hotel.</p><p>Hotel de Malle Moolen is gemakkelijk te bereiken met de auto of het openbaar vervoer. Vanaf Schiphol gaat er een speciale shuttle bus. Het Centraal Station is op een afstand van 100 meter en diverse parkeergarages liggen vlakbij het hotel.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/63b2fe61cdc49f5de115f2a9/malle_moolen.jpg",
#     "images": [
#       {
#         "id": "fa074d03-d73b-4ec9-9b4f-b488ab4c67b2",
#         "src": "https://app.thefeedfactory.nl/api/assets/63b2fe61cdc49f5de115f2a9/malle_moolen.jpg",
#         "copyright": "De Malle Moolen",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": true,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Warmoesstraat",
#       "houseNumber": "7",
#       "zipcode": "1012 HT",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.376102,
#       "lng": 4.89937
#     },
#     "phoneNumber": "020 535 3222",
#     "email": "info@mallemoolen.nl",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "eb143234-2b59-41b5-955b-96c5322211e4",
#         "url": "https://www.mallemoolen.nl/"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/overnachten/accommodaties/de-malle-moolen"
#   },
#   {
#     "kind": "Location",
#     "id": "6ff12455-9ed0-43c5-816a-530d075306a5",
#     "ffID": "5b068ca2adbe1d0001d28714",
#     "slug": "uit/agenda/winkelen/winkels/beadies",
#     "name": "Beadies",
#     "category": [
#       {
#         "title": "Winkels",
#         "slug": "uit/agenda/winkelen/winkels"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "winkelen",
#       "winkels",
#       "beadies"
#     ],
#     "seo_title": "Beadies",
#     "seo_description": "Als je Beadies in de Huidenstraat binnenloopt, glimmen de kralen en strass-steentjes je tegemoet. In de fleurige kralen- en sieradenwinkel kun je als creatieveling zelf aan de slag met een overweldigende hoeveelheid kralen, steentjes, bedeltjes en slotjes.",
#     "seo_slug": "uit/agenda/winkelen/winkels/beadies",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/5ff888a2de7e8633a4aaacb0/bbbce722-d2e7-4732-9406-c8a0d9b8d714.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/shopping/shops/beadies"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/winkelen/winkels/beadies"
#       }
#     ],
#     "intro": "Als je Beadies in de Huidenstraat binnenloopt, glimmen de kralen en strass-steentjes je tegemoet. In de fleurige kralen- en sieradenwinkel kun je als creatieveling zelf aan de slag met een overweldigende hoeveelheid kralen, steentjes, bedeltjes en slotjes.",
#     "description_html": "<p>Wil je liever niet zelf aan het werk? Geen probleem: ze hebben hier ook kant-en-klare kettingen, oorbellen en armbandjes.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/5ff888a2de7e8633a4aaacb0/bbbce722-d2e7-4732-9406-c8a0d9b8d714.jpg",
#     "images": [
#       {
#         "id": "a065f9e2-bc7b-44ba-809a-2d889934eb48",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff888a2de7e8633a4aaacb0/bbbce722-d2e7-4732-9406-c8a0d9b8d714.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [
#         {
#           "closeDay": "MONDAY",
#           "closeTime": "18:00",
#           "openDay": "MONDAY",
#           "openTime": "11:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "TUESDAY",
#           "closeTime": "18:00",
#           "openDay": "TUESDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "WEDNESDAY",
#           "closeTime": "18:00",
#           "openDay": "WEDNESDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "THURSDAY",
#           "closeTime": "18:00",
#           "openDay": "THURSDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "FRIDAY",
#           "closeTime": "18:00",
#           "openDay": "FRIDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SATURDAY",
#           "closeTime": "18:00",
#           "openDay": "SATURDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SUNDAY",
#           "closeTime": "18:00",
#           "openDay": "SUNDAY",
#           "openTime": "12:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         }
#       ],
#       "specialHours": []
#     },
#     "openUntil": "18:00",
#     "soldOut": false,
#     "address": {
#       "street": "Huidenstraat",
#       "houseNumber": "6",
#       "zipcode": "1016 ES",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.368838,
#       "lng": 4.886056
#     },
#     "phoneNumber": "020 428 5161",
#     "email": null,
#     "urls": [
#       {
#         "type": "Website",
#         "id": "80f78197-0fc0-4ac4-ab50-fd4ba3152074",
#         "url": "http://www.beadies.nl/"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/winkelen/winkels/beadies"
#   },
#   {
#     "kind": "Location",
#     "id": "59103f63-a27c-437b-92fa-e770688cb6a2",
#     "ffID": "60dd7a42eae7cc6fc6da0b12",
#     "slug": "whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours",
#     "name": "That Dam Guide - Amsterdam Private Tours",
#     "category": [
#       {
#         "title": "Tours",
#         "slug": "whats-on/calendar/attractions-and-sights/tours"
#       }
#     ],
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "attractions-and-sights",
#       "tours",
#       "that-dam-guide-amsterdam-private-tours"
#     ],
#     "seo_title": "That Dam Guide - Amsterdam Private Tours",
#     "seo_description": "We love providing personal bespoke private tours of Amsterdam and the surrounding countryside that can be shaped to your interests and go at your pace, from quick to leisurely.  That Dam Guide is made up of 5 dedicated guides who have honed our craft for many years and love sharing our beautiful town.",
#     "seo_slug": "whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/60dd7ba9eae7cc6fc6da0b1b/DamGuide1.jpeg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/tours/that-dam-guide-amsterdam-private-tours"
#       }
#     ],
#     "intro": "We love providing personal bespoke private tours of Amsterdam and the surrounding countryside that can be shaped to your interests and go at your pace, from quick to leisurely.  That Dam Guide is made up of 5 dedicated guides who have honed our craft for many years and love sharing our beautiful town.",
#     "description_html": "<h2>Different private tours on offer</h2>\n<p>We have a wide range of tours available, both walking and driving. &nbsp;Amsterdam lends itself to walking tours in the historic centre and our most popular tour is a 3 hour walk, with breaks of course, that takes in the main sights and gives a great overview of the history and culture of the city. &nbsp;We can have many subject that we can focus the tours on and we discuss this with you by email as part of the booking process: design, business, the Golden Age, Jewish History, Rembrandt and the Rijk Museum, Red Light District. &nbsp;We offer tours to other towns as well, Haarlem, The Hague, Delft, Monnickemdam, Edam and in April we visit Tulip Fields and the rest of the summer we offer authentic Countryside &amp; Windmill experiences.&nbsp;</p>\n<p><a href=\"https://thatdamguide.com/amsterdam-private-tours/\"><u><strong>thatdamguide.com/amsterdam-private-tours/</strong></u></a></p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/60dd7ba9eae7cc6fc6da0b1b/DamGuide1.jpeg",
#     "images": [
#       {
#         "id": "a7f65ff5-f124-4c93-8e7f-91ef567d40cc",
#         "src": "https://app.thefeedfactory.nl/api/assets/60dd7ba9eae7cc6fc6da0b1b/DamGuide1.jpeg",
#         "copyright": "That Dam Guide",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "97e0017d-8166-4b59-9817-a65121237664",
#         "src": "https://app.thefeedfactory.nl/api/assets/60dd7bbbeae7cc6fc6da0b1c/DamGuide2.jpeg",
#         "copyright": "That Dam Guide",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "53e2685c-f8f6-4995-8a25-a6007d59d60a",
#         "src": "https://app.thefeedfactory.nl/api/assets/60dd7bd3eae7cc6fc6da0b1d/DamGuide3.jpeg",
#         "copyright": "That Dam Guide",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Prins Hendrikkade",
#       "houseNumber": null,
#       "zipcode": "1012 AD",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.3766264,
#       "lng": 4.9005523
#     },
#     "phoneNumber": null,
#     "email": null,
#     "urls": null,
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/that-dam-guide-amsterdam-private-tours"
#   },
#   {
#     "kind": "Location",
#     "id": "5049665f-6253-4545-ab8b-abfe2361cda2",
#     "ffID": "5b069723adbe1d0001d31a40",
#     "slug": "whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge",
#     "name": "Smart Phone City Challenge",
#     "category": [
#       {
#         "title": "Tours",
#         "slug": "whats-on/calendar/attractions-and-sights/tours"
#       }
#     ],
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "attractions-and-sights",
#       "tours",
#       "smart-phone-city-challenge"
#     ],
#     "seo_title": "Smart Phone City Challenge",
#     "seo_description": "Use your smart phone to compete against your colleagues during this fun and friendly event. The company will create a WhatsApp group for every team. An instructor will then send challenges to every group which must be completed at certain locations in Amsterdam. You just have to send photos, videos or messages to prove you have succeeded in each challenge. Not only is it a great way to discover this beautiful city, it’s a fantastic team building exercise.",
#     "seo_slug": "whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/5ff89448de7e8633a4ab14f2/fe2d9647-edab-48d6-8415-7b6bcf93594d.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/tours/smartphone-city-challenge"
#       }
#     ],
#     "intro": "Use your smart phone to compete against your colleagues during this fun and friendly event. The company will create a WhatsApp group for every team. An instructor will then send challenges to every group which must be completed at certain locations in Amsterdam. You just have to send photos, videos or messages to prove you have succeeded in each challenge. Not only is it a great way to discover this beautiful city, it’s a fantastic team building exercise.",
#     "description_html": "This event is  <a href=\"http://www.en.bethereevents.nl/city-games-amsterdam/smarthphone-city-challenge-amsterdam&quot;\">bookable with </a>a minimum of ten participants.",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/5ff89448de7e8633a4ab14f2/fe2d9647-edab-48d6-8415-7b6bcf93594d.jpg",
#     "images": [
#       {
#         "id": "bc4cc746-9a18-42c7-a53f-ad07016378b4",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff89448de7e8633a4ab14f2/fe2d9647-edab-48d6-8415-7b6bcf93594d.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Oudebrugsteeg",
#       "houseNumber": "9",
#       "zipcode": "1012 JN",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.375538,
#       "lng": 4.896846
#     },
#     "phoneNumber": "020 767 0094",
#     "email": "info@bethereevents.nl",
#     "urls": null,
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/smart-phone-city-challenge"
#   },
#   {
#     "kind": "Location",
#     "id": "82b91c5d-550c-41f7-b857-9a18dd800aca",
#     "ffID": "5b068ca2adbe1d0001d28724",
#     "slug": "whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium",
#     "name": "Palladium",
#     "category": [
#       {
#         "title": "Cafés and bars",
#         "slug": "whats-on/calendar/eating-and-drinking/cafes-and-bars"
#       }
#     ],
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "eating-and-drinking",
#       "cafes-and-bars",
#       "palladium"
#     ],
#     "seo_title": "Palladium",
#     "seo_description": "Discover parties with guest DJ's from Thursday through Saturday nights. You won't find a better hot spot to celebrate your next birthday or other special event. With throwback and daily cocktails.\nPalladium serves Modern European classics and high quality local favorites.",
#     "seo_slug": "whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/63b3f805cdc49f5de1163ab5/palladium.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/eten-en-drinken/cafes-en-bars/palladium"
#       }
#     ],
#     "intro": "Discover parties with guest DJ's from Thursday through Saturday nights. You won't find a better hot spot to celebrate your next birthday or other special event. With throwback and daily cocktails.\nPalladium serves Modern European classics and high quality local favorites.",
#     "description_html": null,
#     "main_image": "https://app.thefeedfactory.nl/api/assets/63b3f805cdc49f5de1163ab5/palladium.jpg",
#     "images": [
#       {
#         "id": "790c5196-2beb-4013-ab08-fced76fb9603",
#         "src": "https://app.thefeedfactory.nl/api/assets/63b3f805cdc49f5de1163ab5/palladium.jpg",
#         "copyright": "Palladium Amsterdam",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [
#         {
#           "closeDay": "TUESDAY",
#           "closeTime": "01:00",
#           "openDay": "MONDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "WEDNESDAY",
#           "closeTime": "01:00",
#           "openDay": "TUESDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "THURSDAY",
#           "closeTime": "01:00",
#           "openDay": "WEDNESDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "FRIDAY",
#           "closeTime": "01:00",
#           "openDay": "THURSDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SATURDAY",
#           "closeTime": "03:00",
#           "openDay": "FRIDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SUNDAY",
#           "closeTime": "03:00",
#           "openDay": "SATURDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "MONDAY",
#           "closeTime": "01:00",
#           "openDay": "SUNDAY",
#           "openTime": "10:30",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         }
#       ],
#       "specialHours": []
#     },
#     "openUntil": "01:00",
#     "soldOut": false,
#     "address": {
#       "street": "Kleine-Gartmanplantsoen",
#       "houseNumber": "7",
#       "zipcode": "1017 RP",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.362811,
#       "lng": 4.883481
#     },
#     "phoneNumber": "020 620 5536",
#     "email": null,
#     "urls": null,
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/eating-and-drinking/cafes-and-bars/palladium"
#   },
#   {
#     "kind": "Location",
#     "id": "4f14d9c9-1da4-4544-8fb9-f33f78872b7a",
#     "ffID": "5b069bb7adbe1d0001d3445c",
#     "slug": "uit/agenda/eten-en-drinken/restaurants/taiko",
#     "name": "Taiko",
#     "category": [
#       {
#         "title": "Restaurants",
#         "slug": "uit/agenda/eten-en-drinken/restaurants"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "eten-en-drinken",
#       "restaurants",
#       "taiko"
#     ],
#     "seo_title": "Taiko",
#     "seo_description": "Het Aziatische restaurant Taiko, in het Conservatorium Hotel, biedt een uitgebreid menu vol Oosterse heerlijkheden. Er wordt alleen gebruikgemaakt van verse, lokale producten en exclusieve geïmporteerde ingrediënten.",
#     "seo_slug": "uit/agenda/eten-en-drinken/restaurants/taiko",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/5ff89992de7e8633a4ab4e2a/9fe6571e-31d3-4dd2-9c0b-8258f82c5f0b.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/eating-and-drinking/restaurants/taiko"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/eten-en-drinken/restaurants/taiko"
#       }
#     ],
#     "intro": "Het Aziatische restaurant Taiko, in het Conservatorium Hotel, biedt een uitgebreid menu vol Oosterse heerlijkheden. Er wordt alleen gebruikgemaakt van verse, lokale producten en exclusieve geïmporteerde ingrediënten.",
#     "description_html": "<h2>Noordzeevis en Wagyu Beef</h2><p>Het menu en de aankleding van het restaurant behoren tot het concept van chef Schilo van Coevorden, die veel heeft gereisd en geleerd in Azië. De combinatie van lokale producten met Aziatische smaken zorgt voor een geheel nieuwe kijk op de Aziatische keuken. Als je overweldigd bent door het enorme aanbod op de menukaart kun je kiezen voor een vier- of achtgangenmenu.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/5ff89992de7e8633a4ab4e2a/9fe6571e-31d3-4dd2-9c0b-8258f82c5f0b.jpg",
#     "images": [
#       {
#         "id": "bffba64f-a05d-4dc2-8a13-7aeb756ab6ae",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff89992de7e8633a4ab4e2a/9fe6571e-31d3-4dd2-9c0b-8258f82c5f0b.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "ea73fd4a-f7c7-4386-b125-487794db1db0",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff89993de7e8633a4ab4e3c/9abf2d5f-e111-4254-a8dc-0f0f02f9c6d3.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "51eb0cf1-3cf3-4495-82f4-84ad9eb2044a",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff89994de7e8633a4ab4e4a/f693b846-fd2b-4f81-85f1-287657594eec.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "41eb7501-1490-4ff1-aa56-b196ac2e195b",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff89995de7e8633a4ab4e55/f92f675c-58a3-490d-a2ed-171bba108999.jpg",
#         "copyright": "Rinze Vegelien",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [
#         {
#           "closeDay": "WEDNESDAY",
#           "closeTime": "00:00",
#           "openDay": "TUESDAY",
#           "openTime": "18:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "THURSDAY",
#           "closeTime": "00:00",
#           "openDay": "WEDNESDAY",
#           "openTime": "18:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "FRIDAY",
#           "closeTime": "00:00",
#           "openDay": "THURSDAY",
#           "openTime": "18:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SATURDAY",
#           "closeTime": "00:00",
#           "openDay": "FRIDAY",
#           "openTime": "18:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SUNDAY",
#           "closeTime": "00:00",
#           "openDay": "SATURDAY",
#           "openTime": "18:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         }
#       ],
#       "specialHours": []
#     },
#     "openUntil": "00:00",
#     "soldOut": false,
#     "address": {
#       "street": "Van Baerlestraat",
#       "houseNumber": "27",
#       "zipcode": "1071 AN",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.358624,
#       "lng": 4.878628
#     },
#     "phoneNumber": null,
#     "email": null,
#     "urls": [
#       {
#         "type": "Website",
#         "id": "6a861875-e76f-4d68-84c8-5af2322bb1df",
#         "url": "https://www.conservatoriumhotel.com/nl/taiko"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/eten-en-drinken/restaurants/taiko"
#   },
#   {
#     "kind": "Location",
#     "id": "f9db5b65-fff6-44b6-9c9e-8a8a0b79b874",
#     "ffID": "5b068cf9adbe1d0001d28f37",
#     "slug": "uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam",
#     "name": "RAI Amsterdam",
#     "category": [
#       {
#         "title": "Theater en podiumkunsten",
#         "slug": "uit/agenda/voorstellingen/theater-en-podiumkunsten"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "voorstellingen",
#       "theater-en-podiumkunsten",
#       "rai-amsterdam"
#     ],
#     "seo_title": "RAI Amsterdam",
#     "seo_description": "RAI is het bekende conferentiecentrum in Amsterdam, maar er zijn hier ook regelmatig theatervoorstellingen, concerten en musicals.",
#     "seo_slug": "uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/5ff88988de7e8633a4aab7cb/4c263d3d-86eb-4247-ab4c-56caddd0eb05.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/theatre-and-stage/stage/rai-amsterdam"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam"
#       }
#     ],
#     "intro": "RAI is het bekende conferentiecentrum in Amsterdam, maar er zijn hier ook regelmatig theatervoorstellingen, concerten en musicals.",
#     "description_html": "<h2>Multifunctionele beurslocatie&nbsp;</h2><p>Bij multifunctionele beurslocatie RAI Amsterdam is er ook veel gelegenheid tot ontspanning met theater, toneel, musical en muziek. Er staan met grote regelmaat grote shows, popconcerten, musicals, culinaire festivals en klassieke concerten op het programma.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/5ff88988de7e8633a4aab7cb/4c263d3d-86eb-4247-ab4c-56caddd0eb05.jpg",
#     "images": [
#       {
#         "id": "765a03a8-7413-438a-9d9a-b1684ba2a0fe",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff88988de7e8633a4aab7cb/4c263d3d-86eb-4247-ab4c-56caddd0eb05.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Europaboulevard",
#       "houseNumber": "22",
#       "zipcode": "1078 RV",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.339047,
#       "lng": 4.891153
#     },
#     "phoneNumber": "020 549 1212",
#     "email": "raimarketing@rai.nl",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "8da7871f-adbc-45cd-aa70-e4c163330e67",
#         "url": "https://www.rai.nl/theater-bezoeken"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/voorstellingen/theater-en-podiumkunsten/rai-amsterdam"
#   },
#   {
#     "kind": "Location",
#     "id": "7967cafa-c68f-415c-939b-a62c3b81f075",
#     "ffID": "5b06b357adbe1d0001d3deed",
#     "slug": "uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas",
#     "name": "Watersportcentrum Sloterplas",
#     "category": [
#       {
#         "title": "Attracties",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/attracties"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "attracties-en-bezienswaardigheden",
#       "attracties",
#       "watersportcentrum-sloterplas"
#     ],
#     "seo_title": "Watersportcentrum Sloterplas",
#     "seo_description": "Watersportcentrum Sloterplas is de locatie om even lekker buiten te zijn in Amsterdam. Zeilen, suppen, windsurfen, kanoën, waterfietsen en genieten van een drankje op ons terras. Het is bij ons allemaal mogelijk!\nVanuit het watersportcentrum bieden wij cursussen, kinderfeestjes, splashweken, schoolsport en privélessen.\nOnze instructeurs staan altijd voor u klaar om samen voor het optimale te gaan. Van cursus tot privéles, van jong tot oud, alles en iedereen kan bij ons terecht.",
#     "seo_slug": "uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/5ffeb88df8ee2771764dfe3d/c2449ff2-1dbb-400c-bf5b-bf5f6cd5141c.jpg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/attractions-and-sights/attractions/watersportcentrum-sloterplas"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas"
#       }
#     ],
#     "intro": "Watersportcentrum Sloterplas is de locatie om even lekker buiten te zijn in Amsterdam. Zeilen, suppen, windsurfen, kanoën, waterfietsen en genieten van een drankje op ons terras. Het is bij ons allemaal mogelijk!\nVanuit het watersportcentrum bieden wij cursussen, kinderfeestjes, splashweken, schoolsport en privélessen.\nOnze instructeurs staan altijd voor u klaar om samen voor het optimale te gaan. Van cursus tot privéles, van jong tot oud, alles en iedereen kan bij ons terecht.",
#     "description_html": "<p>Vanuit het watersportcentrum bieden wij onder andere het volgende aan:</p><p><br></p><p><strong> * zeilcursussen</strong>: Wij bieden zeilcursussen op ieder niveau en voor alle leeftijden aan.&nbsp;Zo hebben wij Optimisten voor kinderen vanaf 8 jaar, Laser Vago’s vanaf 12 jaar als u van een echte uitdaging houdt en voor volwassenen ook Laser Vago’s en een Valk indien u de basis van het zeilen onder de knie wilt krijgen.</p><p> Al onze instructeurs zijn erkend opgeleid en worden regelmatig bijgeschoold.</p><p><br></p><p><strong> * kinderfeestjes</strong>:</p><p> Voor kinderen tussen de 8 en 12 jaar hebben wij 3 spetterende watersportfeestjes: kano, vlottenbouwen of optimist zeilen. Alle feestjes worden begeleid door deskundige instructeurs, die ervoor zorgen dat je jouw feestje nooit meer vergeet!</p><p><br></p><p><strong> * Splashweken</strong>:</p><p> De mei- en zomer vakantie beleef je bij ons op het water. Op de doordeweekse dagen kunnen kinderen t/m 11 jaar of jonger meedoen met de ochtend- en/of middagshift van de Splashweek, voor 12 jaar en ouder zijn dit hele dagen. Met wie je komt maakt niet uit. Of je nou alleen komt of met wat vrienden, iedereen is welkom. Onze instructeurs weten namelijk goed hoe ze iedereen bij de groep kunnen betrekken. Hierdoor leert iedereen elkaar goed kennen en ontstaan de mooiste vriendschappen.&nbsp;</p><p><br></p><p> Onze instructeurs staan altijd voor u klaar om samen voor het optimale te gaan. Van cursus tot privéles, van jong tot oud, alles en iedereen kan bij ons terecht.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/5ffeb88df8ee2771764dfe3d/c2449ff2-1dbb-400c-bf5b-bf5f6cd5141c.jpg",
#     "images": [
#       {
#         "id": "16737f2e-48ec-47b6-9584-98f0c6ed7d06",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ffeb88df8ee2771764dfe3d/c2449ff2-1dbb-400c-bf5b-bf5f6cd5141c.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "f5f3380c-36b8-4eb6-8c04-289d690cf636",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ffeb88ff8ee2771764dfe3e/34b4e172-0371-400d-ba68-ef1ceb58c39d.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [
#         {
#           "closeDay": "WEDNESDAY",
#           "closeTime": "22:00",
#           "openDay": "WEDNESDAY",
#           "openTime": "12:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "THURSDAY",
#           "closeTime": "22:00",
#           "openDay": "THURSDAY",
#           "openTime": "12:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "FRIDAY",
#           "closeTime": "22:00",
#           "openDay": "FRIDAY",
#           "openTime": "12:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SATURDAY",
#           "closeTime": "22:00",
#           "openDay": "SATURDAY",
#           "openTime": "10:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         },
#         {
#           "closeDay": "SUNDAY",
#           "closeTime": "22:00",
#           "openDay": "SUNDAY",
#           "openTime": "10:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         }
#       ],
#       "specialHours": []
#     },
#     "openUntil": "22:00",
#     "soldOut": false,
#     "address": {
#       "street": "Christoffel Plantijngracht",
#       "houseNumber": "4",
#       "zipcode": "1065 DA",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.360322,
#       "lng": 4.815835
#     },
#     "phoneNumber": "020 617 5839",
#     "email": "sloterplas@topsail.nl",
#     "urls": null,
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracties/watersportcentrum-sloterplas"
#   },
#   {
#     "kind": "Location",
#     "id": "349e1d30-e583-461d-86e7-87813361ca86",
#     "ffID": "5b068badadbe1d0001d26d65",
#     "slug": "whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery",
#     "name": "Amsterbike Bike Rental & Delivery",
#     "category": [
#       {
#         "title": "Rental",
#         "slug": "whats-on/calendar/transportation/rental"
#       }
#     ],
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "transportation",
#       "rental",
#       "amsterbike-bike-rental-and-delivery"
#     ],
#     "seo_title": "Amsterbike Bike Rental & Delivery",
#     "seo_description": "Since 2008, AmsterBike has been offering bike rentals, guided tours and delivery for groups and individuals. The bikes have excellent quality with hand brakes, extra locks against theft, gears, and are very well maintained.",
#     "seo_slug": "whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/60b136b865b7c97410edf818/AH1.JPG",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/vervoer/verhuur/amsterbike-fietsverhuur-and-bezorging"
#       }
#     ],
#     "intro": "Since 2008, AmsterBike has been offering bike rentals, guided tours and delivery for groups and individuals. The bikes have excellent quality with hand brakes, extra locks against theft, gears, and are very well maintained.",
#     "description_html": "<h2>Amsterbike</h2><p>Amsterbike is located at the Passenger Terminal, which is a Cruise Terminal within walking distance of Central Station. You can also have bikes delivered to your location. You can download the Amsterbike app with more than ten different sightseeing tours with spoken explanations via GPS in English, German, French and Spanish.</p><p>You can easily park your car there for 12 euros per day. See the possibilities <a href=\"https://www.amsterbike.eu/parkandbike\" rel=\"noopener noreferrer\" target=\"_blank\">here</a>. You can find more information about bike rental <a href=\"https://www.amsterbike.eu/rentabike\" rel=\"noopener noreferrer\" target=\"_blank\">here</a>. For delivery you will <a href=\"https://www.amsterbike.eu/bikedelivery\" rel=\"noopener noreferrer\" target=\"_blank\">find</a> more information here.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/60b136b865b7c97410edf818/AH1.JPG",
#     "images": [
#       {
#         "id": "cis_jrpscq2zuu8",
#         "src": "https://app.thefeedfactory.nl/api/assets/60b136b865b7c97410edf818/AH1.JPG",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "cis_1qm8ns640mn",
#         "src": "https://app.thefeedfactory.nl/api/assets/60b136ce65b7c97410edf819/AH2.JPG",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "cis_hc83onybfrc",
#         "src": "https://app.thefeedfactory.nl/api/assets/60b1375565b7c97410edf81a/BR2.JPG",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "cis_k6pfiw47ccg",
#         "src": "https://app.thefeedfactory.nl/api/assets/60b137b965b7c97410edf81b/Corporate1.jpg",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": [
#         {
#           "closeDay": "MONDAY",
#           "closeTime": "18:00",
#           "openDay": "MONDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         },
#         {
#           "closeDay": "TUESDAY",
#           "closeTime": "18:00",
#           "openDay": "TUESDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         },
#         {
#           "closeDay": "WEDNESDAY",
#           "closeTime": "18:00",
#           "openDay": "WEDNESDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         },
#         {
#           "closeDay": "THURSDAY",
#           "closeTime": "18:00",
#           "openDay": "THURSDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         },
#         {
#           "closeDay": "FRIDAY",
#           "closeTime": "18:00",
#           "openDay": "FRIDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         },
#         {
#           "closeDay": "SATURDAY",
#           "closeTime": "18:00",
#           "openDay": "SATURDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         },
#         {
#           "closeDay": "SUNDAY",
#           "closeTime": "18:00",
#           "openDay": "SUNDAY",
#           "openTime": "09:00",
#           "validFrom": "2025-01-01",
#           "validUntil": "2050-01-01",
#           "isClosed": false
#         }
#       ]
#     },
#     "openUntil": "18:00",
#     "soldOut": false,
#     "address": {
#       "street": "Piet Heinkade",
#       "houseNumber": "25",
#       "zipcode": "1019 BR",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.377824,
#       "lng": 4.915021
#     },
#     "phoneNumber": "+31 20 4199063",
#     "email": "info@amsterbike.eu",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "cis_emx5f8yuxco",
#         "url": "https://www.amsterbike.eu/book"
#       }
#     ],
#     "promotions": [
#       {
#         "id": "cis_8hah2mecrzs",
#         "productName": "city card",
#         "productType": null,
#         "description": "Rent a bike for free for 24 hours with your I amsterdam city card.",
#         "startDate": "2023-12-18 00:00:00",
#         "endDate": "2030-01-01 00:00:00",
#         "published": true,
#         "informationUrl": "https://www.iamsterdam.com/en/whats-on/calendar?benefits_with_the_city_card=freecard&benefits_with_the_city_card=discountcard&benefits_with_the_city_card=giftcard",
#         "bookingUrl": "https://www.iamsterdam.com/en/tickets/i-amsterdam-city-card",
#         "isAuthenticatedOnly": false
#       }
#     ],
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/transportation/rental/amsterbike-bike-rental-and-delivery"
#   },
#   {
#     "kind": "Location",
#     "id": "722f91d6-1409-4137-9481-6e805e7de220",
#     "ffID": "6879071b7c674714bad24079",
#     "slug": "uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst",
#     "name": "Wijnhandel de Geheime Dienst",
#     "category": [
#       {
#         "title": "Winkels",
#         "slug": "uit/agenda/winkelen/winkels"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "winkelen",
#       "winkels",
#       "wijnhandel-de-geheime-dienst"
#     ],
#     "seo_title": "Wijnhandel de Geheime Dienst",
#     "seo_description": "Je kunt bij ons wijn uit eigen import, bier, frisdrank, alcohol vrij, kaas, olijven en veel meer lekkers kopen in onze winkel aan het Zonneplein in Amsterdam-Noord",
#     "seo_slug": "uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/687906d67c674714bad24077/24H_Noord_Campagne_1800x1020_1.webp",
#     "localizations": [
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst"
#       }
#     ],
#     "intro": "Je kunt bij ons wijn uit eigen import, bier, frisdrank, alcohol vrij, kaas, olijven en veel meer lekkers kopen in onze winkel aan het Zonneplein in Amsterdam-Noord",
#     "description_html": null,
#     "main_image": "https://app.thefeedfactory.nl/api/assets/687906d67c674714bad24077/24H_Noord_Campagne_1800x1020_1.webp",
#     "images": [
#       {
#         "id": "645d9c52-e51e-4d36-94e0-56bcfca91008",
#         "src": "https://app.thefeedfactory.nl/api/assets/687906d67c674714bad24077/24H_Noord_Campagne_1800x1020_1.webp",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [
#         {
#           "closeDay": "SATURDAY",
#           "closeTime": "17:00",
#           "openDay": "SATURDAY",
#           "openTime": "11:00",
#           "validFrom": null,
#           "validUntil": null,
#           "isClosed": false
#         }
#       ],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Zonneplein",
#       "houseNumber": "21",
#       "zipcode": "1033 EJ",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.4133694,
#       "lng": 4.890432199999999
#     },
#     "phoneNumber": "06-14239470",
#     "email": "pssst@geheimedienst.eu",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "31d5c62e-9f63-48ff-b7ee-fd4f87e65455",
#         "url": "https://www.geheimedienst.eu"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/winkelen/winkels/wijnhandel-de-geheime-dienst"
#   },
#   {
#     "kind": "Location",
#     "id": "49dc300e-5a23-43e3-b74b-894f2db98eb6",
#     "ffID": "68aedb50d074a82752e0ca51",
#     "slug": "uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert",
#     "name": "R.-K. Begraafplaats Buitenveldert",
#     "category": [
#       {
#         "title": "Bezienswaardigheden",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden"
#       }
#     ],
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "attracties-en-bezienswaardigheden",
#       "bezienswaardigheden",
#       "r-k-begraafplaats-buitenveldert"
#     ],
#     "seo_title": "R.-K. Begraafplaats Buitenveldert",
#     "seo_description": null,
#     "seo_slug": "uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/68aedb4ed074a82752e0ca50/natasjafotografeert-2348.webp",
#     "localizations": [
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert"
#       }
#     ],
#     "intro": null,
#     "description_html": null,
#     "main_image": "https://app.thefeedfactory.nl/api/assets/68aedb4ed074a82752e0ca50/natasjafotografeert-2348.webp",
#     "images": [
#       {
#         "id": "6500d6e9-9d70-4241-8b7a-fc48f0771aab",
#         "src": "https://app.thefeedfactory.nl/api/assets/68aedb4ed074a82752e0ca50/natasjafotografeert-2348.webp",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Fred. Roeskestraat",
#       "houseNumber": "103",
#       "zipcode": "1076 EE",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.34082799999999,
#       "lng": 4.861535
#     },
#     "phoneNumber": null,
#     "email": "info@begraafplaats-buitenveldert.nl",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "54b287e2-8b3c-4789-a9d8-e2373df4069c",
#         "url": "https://begraafplaats-buitenveldert.nl"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/bezienswaardigheden/r-k-begraafplaats-buitenveldert"
#   },
#   {
#     "kind": "Event",
#     "id": "7be1b8d8-b71e-48c2-849f-0bdbd898ef50",
#     "slug": "uit/agenda/festivals/events/het-vrije-westen",
#     "name": "Het Vrije Westen",
#     "directory": "uit",
#     "pages": [
#       "agenda",
#       "festivals",
#       "events",
#       "het-vrije-westen"
#     ],
#     "seo_title": "Het Vrije Westen",
#     "seo_description": "Een van de grootste Bevrijdingsfestivals in Amsterdam is Het Vrije Westen. Dit is wel de plek waar je moet zijn als je van muziek houdt.  Ga naar het Westerpark voor veel livemuziek en nog veel meer. Natuurlijk hopen wij in 2026 terug te keren om wederom met elkaar de vrijheid te vieren.",
#     "seo_slug": "uit/agenda/festivals/events/het-vrije-westen",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/600ab344caf0505bd4cf8310/cf735b61-a960-44b5-a63e-c35a586d02a5.jpg",
#     "localizations": [
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/festivals/events/het-vrije-westen"
#       }
#     ],
#     "intro": "Een van de grootste Bevrijdingsfestivals in Amsterdam is Het Vrije Westen. Dit is wel de plek waar je moet zijn als je van muziek houdt.  Ga naar het Westerpark voor veel livemuziek en nog veel meer. Natuurlijk hopen wij in 2026 terug te keren om wederom met elkaar de vrijheid te vieren.",
# ...
#     "main_image": "https://app.thefeedfactory.nl/api/assets/5ff88c2bde7e8633a4aad184/a5e6ea7c-a470-4fc4-91b0-bb050c3d2719.jpg",
#     "images": [
#       {
#         "id": "bfa0a13a-7eff-4ff0-a6ad-a379f2d1a576",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff88c2bde7e8633a4aad184/a5e6ea7c-a470-4fc4-91b0-bb050c3d2719.jpg",
#         "copyright": "Woeste Westen",
#         "alt": null,
#         "title": "Woeste Westen",
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "6862feff-bc2c-4d90-be30-c6ed0ec990b1",
#         "src": "https://app.thefeedfactory.nl/api/assets/5ff88c2cde7e8633a4aad18d/aacf6b09-fb35-4db9-beb1-1c2121bb116e.jpg",
#         "copyright": "Woeste Westen",
#         "alt": null,
#         "title": "Woeste Westen",
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "alwaysOpen": false,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Overbrakerpad",
#       "houseNumber": "3",
#       "zipcode": "1014 AZ",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.390734,
#       "lng": 4.865178
#     },
#     "phoneNumber": null,
#     "email": "info@woestewesten.nl",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "67071fd1-0026-4fef-8504-7e01e24c9715",
#         "url": "https://www.woestewesten.nl/"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/uit/agenda/attracties-en-bezienswaardigheden/attracties/woeste-westen"
#   },
#   {
#     "kind": "Event",
#     "id": "58ba70ed-889f-4b00-a05b-9d786938fbd9",
#     "slug": "whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble",
#     "name": "A Ukrainian Christmas Partes Ensemble",
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "concerts-and-music",
#       "concerts",
#       "a-ukrainian-christmas-partes-ensemble"
#     ],
#     "seo_title": "A Ukrainian Christmas Partes Ensemble",
#     "seo_description": "Partes Ensemble presents Ukrainian Baroque masterpieces from the 17th and 18th centuries, when Kiev and Lviv were crossroads of musical traditions. Theoretician-composer Mykola Dyletsky brought Italian influences to the East, while child prodigy Maksym Berezovsky propelled the choral concerto to new heights.",
#     "seo_slug": "whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/690a9d86f1ba792b6f15ff93/aHR0cHM6Ly93d3cubXV6aWVrZ2Vib3V3Lm5sLy9jbXNfZmlsZXMvc3lzdGVtL2ltYWdlcy9pbWc4MjM4M19vcmlnLmpwZw.webp",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/concerten-en-muziek/concerten/een-oekraiense-kerst-partes-ensemble"
#       }
#     ],
#     "intro": "Partes Ensemble presents Ukrainian Baroque masterpieces from the 17th and 18th centuries, when Kiev and Lviv were crossroads of musical traditions. Theoretician-composer Mykola Dyletsky brought Italian influences to the East, while child prodigy Maksym Berezovsky propelled the choral concerto to new heights.",
#     "description_html": "<h2>An enchanting winter landscape</h2><p>In powerful 12-part chants and intense four-part miniatures, an enchanting winter wonderland unfolds. Partes brings not only music but also the soul of Ukraine to life.</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/690a9d86f1ba792b6f15ff93/aHR0cHM6Ly93d3cubXV6aWVrZ2Vib3V3Lm5sLy9jbXNfZmlsZXMvc3lzdGVtL2ltYWdlcy9pbWc4MjM4M19vcmlnLmpwZw.webp",
#     "images": [
#       {
#         "id": "310d913b-e90c-4b11-9239-7fdd08a7d56a",
#         "src": "https://app.thefeedfactory.nl/api/assets/690a9d86f1ba792b6f15ff93/aHR0cHM6Ly93d3cubXV6aWVrZ2Vib3V3Lm5sLy9jbXNfZmlsZXMvc3lzdGVtL2ltYWdlcy9pbWc4MjM4M19vcmlnLmpwZw.webp",
#         "copyright": null,
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/jpeg;base64,..."
#       }
#     ],
#     "dates": null,
#     "highlights": [],
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/concerts-and-music/concerts/a-ukrainian-christmas-partes-ensemble"
#   },
#   {
#     "kind": "Location",
#     "id": "8233108f-5bc8-4aa4-8520-6bd96db2b3bc",
#     "ffID": "649bf08dc9c2663697299ff5",
#     "slug": "whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game",
#     "name": "Sherlock Holmes Murder Mystery City Game",
#     "category": [
#       {
#         "title": "Tours",
#         "slug": "whats-on/calendar/attractions-and-sights/tours"
#       }
#     ],
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "attractions-and-sights",
#       "tours",
#       "sherlock-holmes-murder-mystery-city-game"
#     ],
#     "seo_title": "Sherlock Holmes Murder Mystery City Game",
#     "seo_description": "The Sherlock Holmes City Game is a self-guided tour that gives you a fun and interactive way to walk around the city. All you need is a phone with an internet connection. As soon as you book the game, we will send you all the information you need via email.\n\nBy moving around the city, you will unlock assignments. Here you will find characters who are willing to help. But the information comes at a price! Solve their puzzles, take on hilarious photo challenges, chase down culprits and play along to get closer to solving the murder of Balthasar.",
#     "seo_slug": "whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/64acd9ea05b0181027a05a77/Stadsspel_in_Amsterdam.jpeg",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/attracties-en-bezienswaardigheden/tours/sherlock-holmes-moordmysterie-stadsspel"
#       }
#     ],
#     "intro": "The Sherlock Holmes City Game is a self-guided tour that gives you a fun and interactive way to walk around the city. All you need is a phone with an internet connection. As soon as you book the game, we will send you all the information you need via email.\n\nBy moving around the city, you will unlock assignments. Here you will find characters who are willing to help. But the information comes at a price! Solve their puzzles, take on hilarious photo challenges, chase down culprits and play along to get closer to solving the murder of Balthasar.",
#     "description_html": "<h2>Important Information</h2><ul><li>Difficulty level: easy – also suitable for families with children</li><li>Duration:&nbsp;2 hours</li><li>Tickets: You only need to buy 1 ticket per group (1-4 people)</li><li>Each group will play with 1 device. For groups of more than 4 people, you can buy 2 or more tickets.</li><li>To book this game you need to indicate a date and time, but you can start whenever you like.</li></ul><p><br></p><h2>How to play</h2><p>Book the City Game, check the email we send you with the instructions, download the Loquiz App, and begin your gaming experience.</p><h2>What makes the game unique?</h2><p>Explore the city at your own pace while playing the Sherlock Holmes City Game, a self-guided tour that offers a lot of freedom and flexibility. You can play when, where and with whomever you want.</p><p>Whether you want to play alone for personal excitement or with a group of people, this is the game for you.&nbsp;Playing with more groups will turn into a competitive experience, perfect as a teambuilding activity. This game is a fun activity you can do while visiting a city with your family and friends.</p><p>City Game offers the maximum independence: you can play, pause and continue whenever you want. Solve the murder of Balthazar! A fun activity to do when visiting a city with your family or as a couple. 'Sherlock Holmes' is filled with brain teasers, puzzles, hilarious photo tasks, and British humor.</p><p>The Game Sherlock Holmes takes about 1.5 hours, but there is no time limit. You can finish it at your own pace. After you booked the game, you will receive a login code and a simple manual by email. The email contains a QR code, which you can use to easily download the app. You don't need a guide: just download the app, go to the starting point, and you are ready to start the adventure. We recommend playing with 2 to 4 people on one device. Only buy 1 credit per device. If you are playing with more than 4 people, you can buy 2 or more credits.</p><p>Note: this Game uses the city as an interactive playing field, but does not provide any information about the city!</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/64acd9ea05b0181027a05a77/Stadsspel_in_Amsterdam.jpeg",
#     "images": [
#       {
#         "id": "2b26da40-df8a-46b7-9fc0-4dd777d9e361",
#         "src": "https://app.thefeedfactory.nl/api/assets/64acd9ea05b0181027a05a77/Stadsspel_in_Amsterdam.jpeg",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": "Stadsspel in Amsterdam",
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "f67f2d3b-a53a-4b65-9c8c-05e21f374477",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29fb/Sherlock_2.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       },
#       {
#         "id": "9047fb80-08a4-47d1-9206-09f6280eccb4",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29f6/Sherlock_3.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       },
#       {
#         "id": "9eecc340-4c24-41e0-a67f-d109758d2c5c",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29f7/Sherlock_4.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       },
#       {
#         "id": "a685aca3-3a2d-45bf-b362-8d2bd97d50bb",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29f8/Sherlock_5.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       },
#       {
#         "id": "3fd71170-30d2-4107-a7f9-9d6e73faff23",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8cebc32a15c8cb29fc/Sherlock_6.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       },
#       {
#         "id": "45f3773d-863b-44b3-b180-2c38d83faa66",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8bebc32a15c8cb29fa/Sherlock_7.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       },
#       {
#         "id": "1dd287f0-5b20-4877-88e9-e054d874b412",
#         "src": "https://app.thefeedfactory.nl/api/assets/649bef14c9c2663697299feb/Up_Events__Sherlock.jpg",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": "Sherlock Holmes Stadsspel in Amsterdam",
#         "blurDataURL": "data:image/jpeg;base64,..."
#       },
#       {
#         "id": "fa706cfa-8bbb-4062-b966-83a10b2376fa",
#         "src": "https://app.thefeedfactory.nl/api/assets/65979a8aebc32a15c8cb29f4/Sherlock_9.png",
#         "copyright": "UP Digital",
#         "alt": null,
#         "title": null,
#         "blurDataURL": "data:image/png;base64,..."
#       }
#     ],
#     "alwaysOpen": true,
#     "closedDates": null,
#     "businessHours": {
#       "regularHours": [],
#       "specialHours": []
#     },
#     "openUntil": null,
#     "soldOut": false,
#     "address": {
#       "street": "Beursplein",
#       "houseNumber": "5",
#       "zipcode": "1012 JW",
#       "city": "Amsterdam"
#     },
#     "coordinates": {
#       "lat": 52.374333632042685,
#       "lng": 4.895187846449609
#     },
#     "phoneNumber": "+31(0)23 2052340",
#     "email": "hello@citygame.com",
#     "urls": [
#       {
#         "type": "Website",
#         "id": "4c7bbdd7-e642-406b-a3fe-44af131409dd",
#         "url": "https://citygame.com/event/sherlock-holmes-amsterdam/"
#       }
#     ],
#     "promotions": null,
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/attractions-and-sights/tours/sherlock-holmes-murder-mystery-city-game"
#   },
#   {
#     "kind": "Event",
#     "id": "50af38d4-6990-47bf-94b0-01ddf8368376",
#     "slug": "whats-on/calendar/festivals/events/amsterdam-fringe-festival",
#     "name": "Amsterdam Fringe Festival",
#     "directory": "whats-on",
#     "pages": [
#       "calendar",
#       "festivals",
#       "events",
#       "amsterdam-fringe-festival"
#     ],
#     "seo_title": "Amsterdam Fringe Festival",
#     "seo_description": "In September 2026 Amsterdam Fringe Festival presents a new edition with a mix mash of theatre, performance and dance from new, emerging and untamed talent for 11 days. The whole city is our playground; from boat to club to theater, from North to South, you will find us for 11 days at about 22 locations throughout Amsterdam. The festival is an ode to theatrical madness, the independent spirit and a plea for artistic freedom. The program promises another intriguing mix of performances. Please note: Dates and times for 2026 are subject to change",
#     "seo_slug": "whats-on/calendar/festivals/events/amsterdam-fringe-festival",
#     "seo_og_image": "https://app.thefeedfactory.nl/api/assets/687a0b777c674714bad2c53c/Fringe_-_1920x1080_V1__1_.webp",
#     "localizations": [
#       {
#         "locale": "en-GB",
#         "slug": "whats-on/calendar/festivals/events/amsterdam-fringe-festival"
#       },
#       {
#         "locale": "nl-NL",
#         "slug": "uit/agenda/festivals/events/amsterdam-fringe-festival"
#       }
#     ],
#     "intro": "In September 2026 Amsterdam Fringe Festival presents a new edition with a mix mash of theatre, performance and dance from new, emerging and untamed talent for 11 days. The whole city is our playground; from boat to club to theater, from North to South, you will find us for 11 days at about 22 locations throughout Amsterdam. The festival is an ode to theatrical madness, the independent spirit and a plea for artistic freedom. The program promises another intriguing mix of performances. Please note: Dates and times for 2026 are subject to change",
#     "description_html": "<h2>International allure</h2><p>The Amsterdam Fringe Festival is inspired by the festival of the same name in Edinburgh, Adelaide, New York and Dublin. A dive into the Fringe means a dive into the unknown: plunge into the underground, discover the hits of tomorrow and be amazed by a world you never knew existed.</p><h2>Practical information</h2><p>With an appealing international line-up, English speakers can also fully enjoy the Fringe Festival. The starting times indicated are the times of the performance that starts earliest. For detailed information, see the <a href=\"https://amsterdamfringefestival.nl/\" rel=\"noopener noreferrer\" target=\"_blank\">Fringe website</a> .</p>",
#     "main_image": "https://app.thefeedfactory.nl/api/assets/687a0b777c674714bad2c53c/Fringe_-_1920x1080_V1__1_.webp",
#     "images": [
#       {
#         "id": "5ba79de5-7dc5-4d7f-818e-a0e91f897686",
#         "src": "https://app.thefeedfactory.nl/api/assets/687a0b777c674714bad2c53c/Fringe_-_1920x1080_V1__1_.webp",
#         "copyright": null,
#         "alt": null,
#         "title": "Amsterdam Fringe Festival 2025",
#         "blurDataURL": "..."
#       }
#     ],
#     "dates": null,
#     "highlights": [],
#     "source_url": "https://www.iamsterdam.com/en/whats-on/calendar/festivals/events/amsterdam-fringe-festival"
#   }
# ]
# ================================================================================

# %%
# A. Get URLs from Sitemap
urls = get_sitemap_urls()
print(f"Found {len(urls)} potential event/location URLs in sitemap.")

# B. Optional: Slice for testing (remove [:50] to scrape all 3000+)
urls_to_process = urls #[:50] 

print(f"Starting extraction for {len(urls_to_process)} URLs using parallel threads...")

results = []
start_time = time.time()

# C. Run Parallel Scraper
# Using 20 threads implies 20 concurrent connections.
with ThreadPoolExecutor(max_workers=20) as executor:
    futures = {executor.submit(scrape_event_page, url): url for url in urls_to_process}
    
    processed_count = 0
    for future in futures:
        try:
            data = future.result()
            if data:
                results.append(data)
            
            processed_count += 1
            if processed_count % 50 == 0:
                print(f"Processed {processed_count}/{len(urls_to_process)}...")
                
        except Exception as exc:
            print(f"Thread exception: {exc}")

duration = time.time() - start_time
print(f"Scraping completed in {duration:.2f} seconds.")
print(f"Successfully extracted data for {len(results)} items.")

# D. Save to JSON
output_filename = "iamsterdam_data_full.json"
with open(output_filename, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=4, ensure_ascii=False)
    
print(f"Data saved to {output_filename}")

# %% [markdown]
# ## Categories

# %%
# ==============================================================================
# EXTRACT ALL CATEGORIES AND SUBCATEGORIES FROM URLS
# ==============================================================================

def extract_categories_from_urls(urls):
    """
    Extract all unique categories and subcategories from a list of URLs.
    
    Returns a dictionary with structure:
    {
        'nl': {
            'category': ['subcategory1', 'subcategory2', ...],
            ...
        },
        'en': {
            'category': ['subcategory1', 'subcategory2', ...],
            ...
        }
    }
    """
    categories = {
        'nl': {},  # Dutch: /uit/agenda/
        'en': {}   # English: /en/whats-on/calendar/
    }
    
    for url in urls:
        # Parse Dutch URLs: /uit/agenda/category/subcategory/item
        if '/uit/agenda/' in url:
            parts = url.split('/uit/agenda/')
            if len(parts) > 1:
                path_parts = [p for p in parts[1].split('/') if p]  # Remove empty strings
                if len(path_parts) >= 2:
                    category = path_parts[0]
                    subcategory = path_parts[1]
                    
                    if category not in categories['nl']:
                        categories['nl'][category] = set()
                    categories['nl'][category].add(subcategory)
        
        # Parse English URLs: /en/whats-on/calendar/category/subcategory/item
        elif '/whats-on/calendar/' in url:
            parts = url.split('/whats-on/calendar/')
            if len(parts) > 1:
                path_parts = [p for p in parts[1].split('/') if p]  # Remove empty strings
                if len(path_parts) >= 2:
                    category = path_parts[0]
                    subcategory = path_parts[1]
                    
                    if category not in categories['en']:
                        categories['en'][category] = set()
                    categories['en'][category].add(subcategory)
    
    # Convert sets to sorted lists for better readability
    for lang in categories:
        for category in categories[lang]:
            categories[lang][category] = sorted(list(categories[lang][category]))
    
    return categories


def print_category_structure(categories):
    """Pretty print the category structure"""
    print("=" * 80)
    print("CATEGORY STRUCTURE FOR IAMSTERDAM.COM")
    print("=" * 80)
    
    for lang in ['nl', 'en']:
        lang_name = 'Dutch (NL)' if lang == 'nl' else 'English (EN)'
        print(f"\n{lang_name} - /{'uit/agenda/' if lang == 'nl' else 'en/whats-on/calendar/'}")
        print("-" * 80)
        
        for category in sorted(categories[lang].keys()):
            subcategories = categories[lang][category]
            print(f"\n  {category}")
            for subcat in subcategories:
                print(f"    └─ {subcat}")
    
    print("\n" + "=" * 80)


# Get URLs and extract categories
urls = get_sitemap_urls()
categories = extract_categories_from_urls(urls)
print_category_structure(categories)

# Also return as a dictionary for programmatic use
categories
# Out:
# Fetching sitemap from: https://www.iamsterdam.com/sitemap.xml
# ================================================================================
# CATEGORY STRUCTURE FOR IAMSTERDAM.COM
# ================================================================================
#
# Dutch (NL) - /uit/agenda/
# --------------------------------------------------------------------------------
#
#   attracties-en-bezienswaardigheden
#     └─ attracties
#     └─ bezienswaardigheden
#     └─ parken-en-natuurgebieden
#     └─ rondvaarten
#     └─ tours
#
#   concerten-en-muziek
#     └─ concerten
#
#   eten-en-drinken
#     └─ cafes-en-bars
#     └─ restaurants
#
#   festivals
#     └─ events
#
#   musea-en-galeries
#     └─ galeries
#     └─ musea
#
#   nachtleven
#     └─ clubbing
#
#   overnachten
#     └─ accommodaties
#
#   tentoonstellingen
#     └─ alle-tentoonstellingen
#
#   vervoer
#     └─ parkeren
#     └─ verhuur
#
#   voorstellingen
#     └─ theater-en-podiumkunsten
#
#   winkelen
#     └─ markten
#     └─ winkels
#
# English (EN) - /en/whats-on/calendar/
# --------------------------------------------------------------------------------
#
#   accomodations
#     └─ all-accomodations
#
#   attractions-and-sights
#     └─ attractions
#     └─ canal-cruises
#     └─ nature-and-active
#     └─ sights
#     └─ tours
#
#   concerts-and-music
#     └─ concerts
#
#   eating-and-drinking
#     └─ cafes-and-bars
#     └─ restaurants
#
#   exhibitions
#     └─ all-exhibitions
#
#   festivals
#     └─ events
#
#   museums-and-galleries
#     └─ galleries
#     └─ museums
#
#   nightlife
#     └─ clubbing
#
#   shopping
#     └─ markets
#     └─ shops
#
#   theatre-and-stage
#     └─ stage
#
#   transportation
#     └─ parking
#     └─ rental
#
# ================================================================================
# {'nl': {'voorstellingen': ['theater-en-podiumkunsten'],
#   'attracties-en-bezienswaardigheden': ['attracties',
#    'bezienswaardigheden',
#    'parken-en-natuurgebieden',
#    'rondvaarten',
#    'tours'],
#   'vervoer': ['parkeren', 'verhuur'],
#   'musea-en-galeries': ['galeries', 'musea'],
#   'eten-en-drinken': ['cafes-en-bars', 'restaurants'],
#   'festivals': ['events'],
#   'winkelen': ['markten', 'winkels'],
#   'concerten-en-muziek': ['concerten'],
#   'overnachten': ['accommodaties'],
#   'tentoonstellingen': ['alle-tentoonstellingen'],
#   'nachtleven': ['clubbing']},
#  'en': {'eating-and-drinking': ['cafes-and-bars', 'restaurants'],
#   'accomodations': ['all-accomodations'],
#   'transportation': ['parking', 'rental'],
#   'museums-and-galleries': ['galleries', 'museums'],
#   'attractions-and-sights': ['attractions',
#    'canal-cruises',
#    'nature-and-active',
#    'sights',
#    'tours'],
#   'concerts-and-music': ['concerts'],
#   'festivals': ['events'],
#   'shopping': ['markets', 'shops'],
#   'theatre-and-stage': ['stage'],
#   'nightlife': ['clubbing'],
#   'exhibitions': ['all-exhibitions']}}
